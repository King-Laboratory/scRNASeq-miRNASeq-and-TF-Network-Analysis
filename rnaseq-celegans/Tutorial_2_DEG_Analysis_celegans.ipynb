# %% [markdown]
# # RNA-Seq Analysis Training Demo

# %% [markdown]
# ## Overview

# %% [markdown]
# This tutorial will show you the following workflow that is used to generate the list of differentially expressed genes. Running the code in this tutorial should take approximately 15 minutes.
#
# This overflow centers roughly around the useage of the deseq2 package. Documentation for this package can be found here: https://bioconductor.org/packages/release/bioc/vignettes/DESeq2/inst/doc/DESeq2.html
#
# ![RNA-Seq workflow](images/count-workflow.png)

# %%
# Download Miniforge
system('curl -L -O https://github.com/conda-forge/miniforge/releases/latest/download/Miniforge3-$(uname)-$(uname -m).sh', intern = TRUE)

# Install Miniforge
system('bash Miniforge3-$(uname)-$(uname -m).sh -b -u -p $HOME/miniforge', intern = TRUE)

# Add Miniforge bin to the system path
Sys.setenv(PATH = paste(Sys.getenv("HOME"), "/miniforge/bin:", Sys.getenv("PATH"), sep = ""))
# Out:
# character(0)
#   [1] "PREFIX=/home/ec2-user/miniforge"
#   [2] ""
#   [3] "Transaction"
#   [4] ""
#   [5] "  Prefix: /home/ec2-user/miniforge/envs/_virtual_specs_checks"
#   [6] ""
#   [7] "  All requested packages already installed"
#   [8] ""
#   [9] "Dry run. Not executing the transaction."
#  [10] "Unpacking payload ..."
#  [11] "Extracting _libgcc_mutex-0.1-conda_forge.tar.bz2"
#  [12] "Extracting ca-certificates-2024.8.30-hbcca054_0.conda"
#  [13] "Extracting ld_impl_linux-64-2.40-hf3520f5_7.conda"
#  [14] "Extracting pybind11-abi-4-hd8ed1ab_3.tar.bz2"
#  [15] "Extracting python_abi-3.12-5_cp312.conda"
#  [16] "Extracting tzdata-2024a-h8827d51_1.conda"
#  [17] "Extracting libgomp-14.1.0-h77fa898_1.conda"
#  [18] "Extracting _openmp_mutex-4.5-2_gnu.tar.bz2"
#  [19] "Extracting libgcc-14.1.0-h77fa898_1.conda"
#  [20] "Extracting libexpat-2.6.3-h5888daf_0.conda"
#  [21] "Extracting libgcc-ng-14.1.0-h69a702a_1.conda"
#  [22] "Extracting libstdcxx-14.1.0-hc0a3c3a_1.conda"
#  [23] "Extracting openssl-3.3.2-hb9d3cd8_0.conda"
#  [24] "Extracting bzip2-1.0.8-h4bc722e_7.conda"
#  [25] "Extracting c-ares-1.32.3-h4bc722e_0.conda"
#  [26] "Extracting keyutils-1.6.1-h166bdaf_0.tar.bz2"
#  [27] "Extracting libev-4.33-hd590300_2.conda"
#  [28] "Extracting libffi-3.4.2-h7f98852_5.tar.bz2"
#  [29] "Extracting libiconv-1.17-hd590300_2.conda"
#  [30] "Extracting libnsl-2.0.1-hd590300_0.conda"
#  [31] "Extracting libstdcxx-ng-14.1.0-h4852527_1.conda"
#  [32] "Extracting libuuid-2.38.1-h0b41bf4_0.conda"
#  [33] "Extracting libxcrypt-4.4.36-hd590300_1.conda"
#  [34] "Extracting libzlib-1.3.1-h4ab18f5_1.conda"
#  [35] "Extracting lzo-2.10-hd590300_1001.conda"
#  [36] "Extracting ncurses-6.5-he02047a_1.conda"
#  [37] "Extracting reproc-14.2.4.post0-hd590300_1.conda"
#  [38] "Extracting xz-5.2.6-h166bdaf_0.tar.bz2"
#  [39] "Extracting fmt-10.2.1-h00ab1b0_0.conda"
#  [40] "Extracting icu-75.1-he02047a_0.conda"
#  [41] "Extracting libedit-3.1.20191231-he28a2e2_2.tar.bz2"
#  [42] "Extracting libnghttp2-1.58.0-h47da74e_1.conda"
#  [43] "Extracting libsolv-0.7.30-h3509ff9_0.conda"
#  [44] "Extracting libsqlite-3.46.1-hadc24fc_0.conda"
#  [45] "Extracting libssh2-1.11.0-h0841786_0.conda"
#  [46] "Extracting lz4-c-1.9.4-hcb278e6_0.conda"
#  [47] "Extracting readline-8.2-h8228510_1.conda"
#  [48] "Extracting reproc-cpp-14.2.4.post0-h59595ed_1.conda"
#  [49] "Extracting tk-8.6.13-noxft_h4845f30_101.conda"
#  [50] "Extracting yaml-cpp-0.8.0-h59595ed_0.conda"
#  [51] "Extracting zstd-1.5.6-ha6fb4c9_0.conda"
#  [52] "Extracting krb5-1.21.3-h659f571_0.conda"
#  [53] "Extracting libxml2-2.12.7-he7c6b58_4.conda"
#  [54] "Extracting python-3.12.6-hc5c86c4_1_cpython.conda"
#  [55] "Extracting libarchive-3.7.4-hfca40fe_0.conda"
#  [56] "Extracting libcurl-8.10.1-hbbe4b11_0.conda"
#  [57] "Extracting menuinst-2.1.2-py312h7900ff3_1.conda"
#  [58] "Extracting archspec-0.2.3-pyhd8ed1ab_0.conda"
#  [59] "Extracting boltons-24.0.0-pyhd8ed1ab_0.conda"
#  [60] "Extracting brotli-python-1.1.0-py312h2ec8cdc_2.conda"
#  [61] "Extracting certifi-2024.8.30-pyhd8ed1ab_0.conda"
#  [62] "Extracting charset-normalizer-3.3.2-pyhd8ed1ab_0.conda"
#  [63] "Extracting colorama-0.4.6-pyhd8ed1ab_0.tar.bz2"
#  [64] "Extracting distro-1.9.0-pyhd8ed1ab_0.conda"
#  [65] "Extracting frozendict-2.4.4-py312h66e93f0_1.conda"
#  [66] "Extracting hpack-4.0.0-pyh9f0ad1d_0.tar.bz2"
#  [67] "Extracting hyperframe-6.0.1-pyhd8ed1ab_0.tar.bz2"
#  [68] "Extracting idna-3.10-pyhd8ed1ab_0.conda"
#  [69] "Extracting jsonpointer-3.0.0-py312h7900ff3_1.conda"
#  [70] "Extracting libmamba-1.5.9-h4cc3d14_0.conda"
#  [71] "Extracting packaging-24.1-pyhd8ed1ab_0.conda"
#  [72] "Extracting platformdirs-4.3.6-pyhd8ed1ab_0.conda"
#  [73] "Extracting pluggy-1.5.0-pyhd8ed1ab_0.conda"
#  [74] "Extracting pycosat-0.6.6-py312h98912ed_0.conda"
#  [75] "Extracting pycparser-2.22-pyhd8ed1ab_0.conda"
#  [76] "Extracting pysocks-1.7.1-pyha2e5f31_6.tar.bz2"
#  [77] "Extracting ruamel.yaml.clib-0.2.8-py312h98912ed_0.conda"
#  [78] "Extracting setuptools-74.1.2-pyhd8ed1ab_0.conda"
#  [79] "Extracting truststore-0.9.2-pyhd8ed1ab_0.conda"
#  [80] "Extracting wheel-0.44.0-pyhd8ed1ab_0.conda"
#  [81] "Extracting cffi-1.17.1-py312h06ac9bb_0.conda"
#  [82] "Extracting h2-4.1.0-pyhd8ed1ab_0.tar.bz2"
#  [83] "Extracting jsonpatch-1.33-pyhd8ed1ab_0.conda"
#  [84] "Extracting libmambapy-1.5.9-py312h7fb9e8e_0.conda"
#  [85] "Extracting pip-24.2-pyh8b19718_1.conda"
#  [86] "Extracting ruamel.yaml-0.18.6-py312h98912ed_0.conda"
#  [87] "Extracting tqdm-4.66.5-pyhd8ed1ab_0.conda"
#  [88] "Extracting zstandard-0.23.0-py312hef9b889_1.conda"
#  [89] "Extracting conda-package-streaming-0.10.0-pyhd8ed1ab_0.conda"
#  [90] "Extracting urllib3-2.2.3-pyhd8ed1ab_0.conda"
#  [91] "Extracting conda-package-handling-2.3.0-pyh7900ff3_0.conda"
#  [92] "Extracting requests-2.32.3-pyhd8ed1ab_0.conda"
#  [93] "Extracting conda-24.7.1-py312h7900ff3_0.conda"
#  [94] "Extracting conda-libmamba-solver-24.7.0-pyhd8ed1ab_0.conda"
#  [95] "Extracting mamba-1.5.9-py312h9460a1c_0.conda"
#  [96] ""
#  [97] "Installing base environment..."
#  [98] ""
#  [99] "Transaction"
# [100] ""
# [101] "  Prefix: /home/ec2-user/miniforge"
# [102] ""
# [103] "  Updating specs:"
# [104] ""
# [105] "   - conda-forge/linux-64::_libgcc_mutex==0.1=conda_forge[md5=d7c89558ba9fa0495403155b64376d81]"
# [106] "   - conda-forge/linux-64::ca-certificates==2024.8.30=hbcca054_0[md5=c27d1c142233b5bc9ca570c6e2e0c244]"
# [107] "   - conda-forge/linux-64::ld_impl_linux-64==2.40=hf3520f5_7[md5=b80f2f396ca2c28b8c14c437a4ed1e74]"
# [108] "   - conda-forge/noarch::pybind11-abi==4=hd8ed1ab_3[md5=878f923dd6acc8aeb47a75da6c4098be]"
# [109] "   - conda-forge/linux-64::python_abi==3.12=5_cp312[md5=0424ae29b104430108f5218a66db7260]"
# [110] "   - conda-forge/noarch::tzdata==2024a=h8827d51_1[md5=8bfdead4e0fff0383ae4c9c50d0531bd]"
# [111] "   - conda-forge/linux-64::libgomp==14.1.0=h77fa898_1[md5=23c255b008c4f2ae008f81edcabaca89]"
# [112] "   - conda-forge/linux-64::_openmp_mutex==4.5=2_gnu[md5=73aaf86a425cc6e73fcf236a5a46396d]"
# [113] "   - conda-forge/linux-64::libgcc==14.1.0=h77fa898_1[md5=002ef4463dd1e2b44a94a4ace468f5d2]"
# [114] "   - conda-forge/linux-64::libexpat==2.6.3=h5888daf_0[md5=59f4c43bb1b5ef1c71946ff2cbf59524]"
# [115] "   - conda-forge/linux-64::libgcc-ng==14.1.0=h69a702a_1[md5=1efc0ad219877a73ef977af7dbb51f17]"
# [116] "   - conda-forge/linux-64::libstdcxx==14.1.0=hc0a3c3a_1[md5=9dbb9699ea467983ba8a4ba89b08b066]"
# [117] "   - conda-forge/linux-64::openssl==3.3.2=hb9d3cd8_0[md5=4d638782050ab6faa27275bed57e9b4e]"
# [118] "   - conda-forge/linux-64::bzip2==1.0.8=h4bc722e_7[md5=62ee74e96c5ebb0af99386de58cf9553]"
# [119] "   - conda-forge/linux-64::c-ares==1.32.3=h4bc722e_0[md5=7624e34ee6baebfc80d67bac76cc9d9d]"
# [120] "   - conda-forge/linux-64::keyutils==1.6.1=h166bdaf_0[md5=30186d27e2c9fa62b45fb1476b7200e3]"
# [121] "   - conda-forge/linux-64::libev==4.33=hd590300_2[md5=172bf1cd1ff8629f2b1179945ed45055]"
# [122] "   - conda-forge/linux-64::libffi==3.4.2=h7f98852_5[md5=d645c6d2ac96843a2bfaccd2d62b3ac3]"
# [123] "   - conda-forge/linux-64::libiconv==1.17=hd590300_2[md5=d66573916ffcf376178462f1b61c941e]"
# [124] "   - conda-forge/linux-64::libnsl==2.0.1=hd590300_0[md5=30fd6e37fe21f86f4bd26d6ee73eeec7]"
# [125] "   - conda-forge/linux-64::libstdcxx-ng==14.1.0=h4852527_1[md5=bd2598399a70bb86d8218e95548d735e]"
# [126] "   - conda-forge/linux-64::libuuid==2.38.1=h0b41bf4_0[md5=40b61aab5c7ba9ff276c41cfffe6b80b]"
# [127] "   - conda-forge/linux-64::libxcrypt==4.4.36=hd590300_1[md5=5aa797f8787fe7a17d1b0821485b5adc]"
# [128] "   - conda-forge/linux-64::libzlib==1.3.1=h4ab18f5_1[md5=57d7dc60e9325e3de37ff8dffd18e814]"
# [129] "   - conda-forge/linux-64::lzo==2.10=hd590300_1001[md5=ec7398d21e2651e0dcb0044d03b9a339]"
# [130] "   - conda-forge/linux-64::ncurses==6.5=he02047a_1[md5=70caf8bb6cf39a0b6b7efc885f51c0fe]"
# [131] "   - conda-forge/linux-64::reproc==14.2.4.post0=hd590300_1[md5=82ca53502dfd5a64a80dee76dae14685]"
# [132] "   - conda-forge/linux-64::xz==5.2.6=h166bdaf_0[md5=2161070d867d1b1204ea749c8eec4ef0]"
# [133] "   - conda-forge/linux-64::fmt==10.2.1=h00ab1b0_0[md5=35ef8bc24bd34074ebae3c943d551728]"
# [134] "   - conda-forge/linux-64::icu==75.1=he02047a_0[md5=8b189310083baabfb622af68fd9d3ae3]"
# [135] "   - conda-forge/linux-64::libedit==3.1.20191231=he28a2e2_2[md5=4d331e44109e3f0e19b4cb8f9b82f3e1]"
# [136] "   - conda-forge/linux-64::libnghttp2==1.58.0=h47da74e_1[md5=700ac6ea6d53d5510591c4344d5c989a]"
# [137] "   - conda-forge/linux-64::libsolv==0.7.30=h3509ff9_0[md5=02539b77d25aa4f65b20246549e256c3]"
# [138] "   - conda-forge/linux-64::libsqlite==3.46.1=hadc24fc_0[md5=36f79405ab16bf271edb55b213836dac]"
# [139] "   - conda-forge/linux-64::libssh2==1.11.0=h0841786_0[md5=1f5a58e686b13bcfde88b93f547d23fe]"
# [140] "   - conda-forge/linux-64::lz4-c==1.9.4=hcb278e6_0[md5=318b08df404f9c9be5712aaa5a6f0bb0]"
# [141] "   - conda-forge/linux-64::readline==8.2=h8228510_1[md5=47d31b792659ce70f470b5c82fdfb7a4]"
# [142] "   - conda-forge/linux-64::reproc-cpp==14.2.4.post0=h59595ed_1[md5=715e1d720ec1a03715bebd237972fca5]"
# [143] "   - conda-forge/linux-64::tk==8.6.13=noxft_h4845f30_101[md5=d453b98d9c83e71da0741bb0ff4d76bc]"
# [144] "   - conda-forge/linux-64::yaml-cpp==0.8.0=h59595ed_0[md5=965eaacd7c18eb8361fd12bb9e7a57d7]"
# [145] "   - conda-forge/linux-64::zstd==1.5.6=ha6fb4c9_0[md5=4d056880988120e29d75bfff282e0f45]"
# [146] "   - conda-forge/linux-64::krb5==1.21.3=h659f571_0[md5=3f43953b7d3fb3aaa1d0d0723d91e368]"
# [147] "   - conda-forge/linux-64::libxml2==2.12.7=he7c6b58_4[md5=08a9265c637230c37cb1be4a6cad4536]"
# [148] "   - conda-forge/linux-64::python==3.12.6=hc5c86c4_1_cpython[md5=00836baacdca254f28c54d2543e97514]"
# [149] "   - conda-forge/linux-64::libarchive==3.7.4=hfca40fe_0[md5=32ddb97f897740641d8d46a829ce1704]"
# [150] "   - conda-forge/linux-64::libcurl==8.10.1=hbbe4b11_0[md5=6e801c50a40301f6978c53976917b277]"
# [151] "   - conda-forge/linux-64::menuinst==2.1.2=py312h7900ff3_1[md5=c6575ae996f2bc0369c73b632db5ca61]"
# [152] "   - conda-forge/noarch::archspec==0.2.3=pyhd8ed1ab_0[md5=192278292e20704f663b9c766909d67b]"
# [153] "   - conda-forge/noarch::boltons==24.0.0=pyhd8ed1ab_0[md5=61de176bd62041f9cd5bd4fcd09eb0ff]"
# [154] "   - conda-forge/linux-64::brotli-python==1.1.0=py312h2ec8cdc_2[md5=b0b867af6fc74b2a0aa206da29c0f3cf]"
# [155] "   - conda-forge/noarch::certifi==2024.8.30=pyhd8ed1ab_0[md5=12f7d00853807b0531775e9be891cb11]"
# [156] "   - conda-forge/noarch::charset-normalizer==3.3.2=pyhd8ed1ab_0[md5=7f4a9e3fcff3f6356ae99244a014da6a]"
# [157] "   - conda-forge/noarch::colorama==0.4.6=pyhd8ed1ab_0[md5=3faab06a954c2a04039983f2c4a50d99]"
# [158] "   - conda-forge/noarch::distro==1.9.0=pyhd8ed1ab_0[md5=bbdb409974cd6cb30071b1d978302726]"
# [159] "   - conda-forge/linux-64::frozendict==2.4.4=py312h66e93f0_1[md5=82a14d06575c4023a5df6b0798acff71]"
# [160] "   - conda-forge/noarch::hpack==4.0.0=pyh9f0ad1d_0[md5=914d6646c4dbb1fd3ff539830a12fd71]"
# [161] "   - conda-forge/noarch::hyperframe==6.0.1=pyhd8ed1ab_0[md5=9f765cbfab6870c8435b9eefecd7a1f4]"
# [162] "   - conda-forge/noarch::idna==3.10=pyhd8ed1ab_0[md5=7ba2ede0e7c795ff95088daf0dc59753]"
# [163] "   - conda-forge/linux-64::jsonpointer==3.0.0=py312h7900ff3_1[md5=6b51f7459ea4073eeb5057207e2e1e3d]"
# [164] "   - conda-forge/linux-64::libmamba==1.5.9=h4cc3d14_0[md5=896cece5b883ad86e9dd88b1f4d23c99]"
# [165] "   - conda-forge/noarch::packaging==24.1=pyhd8ed1ab_0[md5=cbe1bb1f21567018ce595d9c2be0f0db]"
# [166] "   - conda-forge/noarch::platformdirs==4.3.6=pyhd8ed1ab_0[md5=fd8f2b18b65bbf62e8f653100690c8d2]"
# [167] "   - conda-forge/noarch::pluggy==1.5.0=pyhd8ed1ab_0[md5=d3483c8fc2dc2cc3f5cf43e26d60cabf]"
# [168] "   - conda-forge/linux-64::pycosat==0.6.6=py312h98912ed_0[md5=8f1c372e7b843167be885dc8229931c1]"
# [169] "   - conda-forge/noarch::pycparser==2.22=pyhd8ed1ab_0[md5=844d9eb3b43095b031874477f7d70088]"
# [170] "   - conda-forge/noarch::pysocks==1.7.1=pyha2e5f31_6[md5=2a7de29fb590ca14b5243c4c812c8025]"
# [171] "   - conda-forge/linux-64::ruamel.yaml.clib==0.2.8=py312h98912ed_0[md5=05f31c2a79ba61df8d6d903ce4a4ce7b]"
# [172] "   - conda-forge/noarch::setuptools==74.1.2=pyhd8ed1ab_0[md5=56c9c11d004428e81d02eeb730fc6336]"
# [173] "   - conda-forge/noarch::truststore==0.9.2=pyhd8ed1ab_0[md5=f14e46d1bf271e748ff556d8b872e28a]"
# [174] "   - conda-forge/noarch::wheel==0.44.0=pyhd8ed1ab_0[md5=d44e3b085abcaef02983c6305b84b584]"
# [175] "   - conda-forge/linux-64::cffi==1.17.1=py312h06ac9bb_0[md5=a861504bbea4161a9170b85d4d2be840]"
# [176] "   - conda-forge/noarch::h2==4.1.0=pyhd8ed1ab_0[md5=b748fbf7060927a6e82df7cb5ee8f097]"
# [177] "   - conda-forge/noarch::jsonpatch==1.33=pyhd8ed1ab_0[md5=bfdb7c5c6ad1077c82a69a8642c87aff]"
# [178] "   - conda-forge/linux-64::libmambapy==1.5.9=py312h7fb9e8e_0[md5=ccaeeb6e3caaf0c744480393791aa366]"
# [179] "   - conda-forge/noarch::pip==24.2=pyh8b19718_1[md5=6c78fbb8ddfd64bcb55b5cbafd2d2c43]"
# [180] "   - conda-forge/linux-64::ruamel.yaml==0.18.6=py312h98912ed_0[md5=a99a06a875138829ef65f44bbe2c30ca]"
# [181] "   - conda-forge/noarch::tqdm==4.66.5=pyhd8ed1ab_0[md5=c6e94fc2b2ec71ea33fe7c7da259acb4]"
# [182] "   - conda-forge/linux-64::zstandard==0.23.0=py312hef9b889_1[md5=8b7069e9792ee4e5b4919a7a306d2e67]"
# [183] "   - conda-forge/noarch::conda-package-streaming==0.10.0=pyhd8ed1ab_0[md5=3480386e00995f7a1dfb3b9aa2fe70fd]"
# [184] "   - conda-forge/noarch::urllib3==2.2.3=pyhd8ed1ab_0[md5=6b55867f385dd762ed99ea687af32a69]"
# [185] "   - conda-forge/noarch::conda-package-handling==2.3.0=pyh7900ff3_0[md5=0a7dce281ae2be81acab0aa963e6bb99]"
# [186] "   - conda-forge/noarch::requests==2.32.3=pyhd8ed1ab_0[md5=5ede4753180c7a550a443c430dc8ab52]"
# [187] "   - conda-forge/linux-64::conda==24.7.1=py312h7900ff3_0[md5=e1bf59014e88eaff036101358f63a496]"
# [188] "   - conda-forge/noarch::conda-libmamba-solver==24.7.0=pyhd8ed1ab_0[md5=857c9e25f0a77c0bd7eb622d46d9418f]"
# [189] "   - conda-forge/linux-64::mamba==1.5.9=py312h9460a1c_0[md5=a8525c8a1647b4f5967fa6b552722851]"
# [190] ""
# [191] ""
# [192] "  Package                         Version  Build               Channel         Size"
# [193] "─────────────────────────────────────────────────────────────────────────────────────"
# [194] "  Install:"
# [195] "─────────────────────────────────────────────────────────────────────────────────────"
# [196] ""
# [197] "  + _libgcc_mutex                     0.1  conda_forge         conda-forge         "
# [198] "  + ca-certificates             2024.8.30  hbcca054_0          conda-forge         "
# [199] "  + ld_impl_linux-64                 2.40  hf3520f5_7          conda-forge         "
# [200] "  + pybind11-abi                        4  hd8ed1ab_3          conda-forge         "
# [201] "  + python_abi                       3.12  5_cp312             conda-forge         "
# [202] "  + tzdata                          2024a  h8827d51_1          conda-forge         "
# [203] "  + libgomp                        14.1.0  h77fa898_1          conda-forge         "
# [204] "  + _openmp_mutex                     4.5  2_gnu               conda-forge         "
# [205] "  + libgcc                         14.1.0  h77fa898_1          conda-forge         "
# [206] "  + libexpat                        2.6.3  h5888daf_0          conda-forge         "
# [207] "  + libgcc-ng                      14.1.0  h69a702a_1          conda-forge         "
# [208] "  + libstdcxx                      14.1.0  hc0a3c3a_1          conda-forge         "
# [209] "  + openssl                         3.3.2  hb9d3cd8_0          conda-forge         "
# [210] "  + bzip2                           1.0.8  h4bc722e_7          conda-forge         "
# [211] "  + c-ares                         1.32.3  h4bc722e_0          conda-forge         "
# [212] "  + keyutils                        1.6.1  h166bdaf_0          conda-forge         "
# [213] "  + libev                            4.33  hd590300_2          conda-forge         "
# [214] "  + libffi                          3.4.2  h7f98852_5          conda-forge         "
# [215] "  + libiconv                         1.17  hd590300_2          conda-forge         "
# [216] "  + libnsl                          2.0.1  hd590300_0          conda-forge         "
# [217] "  + libstdcxx-ng                   14.1.0  h4852527_1          conda-forge         "
# [218] "  + libuuid                        2.38.1  h0b41bf4_0          conda-forge         "
# [219] "  + libxcrypt                      4.4.36  hd590300_1          conda-forge         "
# [220] "  + libzlib                         1.3.1  h4ab18f5_1          conda-forge         "
# [221] "  + lzo                              2.10  hd590300_1001       conda-forge         "
# [222] "  + ncurses                           6.5  he02047a_1          conda-forge         "
# [223] "  + reproc                   14.2.4.post0  hd590300_1          conda-forge         "
# [224] "  + xz                              5.2.6  h166bdaf_0          conda-forge         "
# [225] "  + fmt                            10.2.1  h00ab1b0_0          conda-forge         "
# [226] "  + icu                              75.1  he02047a_0          conda-forge         "
# [227] "  + libedit                  3.1.20191231  he28a2e2_2          conda-forge         "
# [228] "  + libnghttp2                     1.58.0  h47da74e_1          conda-forge         "
# [229] "  + libsolv                        0.7.30  h3509ff9_0          conda-forge         "
# [230] "  + libsqlite                      3.46.1  hadc24fc_0          conda-forge         "
# [231] "  + libssh2                        1.11.0  h0841786_0          conda-forge         "
# [232] "  + lz4-c                           1.9.4  hcb278e6_0          conda-forge         "
# [233] "  + readline                          8.2  h8228510_1          conda-forge         "
# [234] "  + reproc-cpp               14.2.4.post0  h59595ed_1          conda-forge         "
# [235] "  + tk                             8.6.13  noxft_h4845f30_101  conda-forge         "
# [236] "  + yaml-cpp                        0.8.0  h59595ed_0          conda-forge         "
# [237] "  + zstd                            1.5.6  ha6fb4c9_0          conda-forge         "
# [238] "  + krb5                           1.21.3  h659f571_0          conda-forge         "
# [239] "  + libxml2                        2.12.7  he7c6b58_4          conda-forge         "
# [240] "  + python                         3.12.6  hc5c86c4_1_cpython  conda-forge         "
# [241] "  + libarchive                      3.7.4  hfca40fe_0          conda-forge         "
# [242] "  + libcurl                        8.10.1  hbbe4b11_0          conda-forge         "
# [243] "  + menuinst                        2.1.2  py312h7900ff3_1     conda-forge         "
# [244] "  + archspec                        0.2.3  pyhd8ed1ab_0        conda-forge         "
# [245] "  + boltons                        24.0.0  pyhd8ed1ab_0        conda-forge         "
# [246] "  + brotli-python                   1.1.0  py312h2ec8cdc_2     conda-forge         "
# [247] "  + certifi                     2024.8.30  pyhd8ed1ab_0        conda-forge         "
# [248] "  + charset-normalizer              3.3.2  pyhd8ed1ab_0        conda-forge         "
# [249] "  + colorama                        0.4.6  pyhd8ed1ab_0        conda-forge         "
# [250] "  + distro                          1.9.0  pyhd8ed1ab_0        conda-forge         "
# [251] "  + frozendict                      2.4.4  py312h66e93f0_1     conda-forge         "
# [252] "  + hpack                           4.0.0  pyh9f0ad1d_0        conda-forge         "
# [253] "  + hyperframe                      6.0.1  pyhd8ed1ab_0        conda-forge         "
# [254] "  + idna                             3.10  pyhd8ed1ab_0        conda-forge         "
# [255] "  + jsonpointer                     3.0.0  py312h7900ff3_1     conda-forge         "
# [256] "  + libmamba                        1.5.9  h4cc3d14_0          conda-forge         "
# [257] "  + packaging                        24.1  pyhd8ed1ab_0        conda-forge         "
# [258] "  + platformdirs                    4.3.6  pyhd8ed1ab_0        conda-forge         "
# [259] "  + pluggy                          1.5.0  pyhd8ed1ab_0        conda-forge         "
# [260] "  + pycosat                         0.6.6  py312h98912ed_0     conda-forge         "
# [261] "  + pycparser                        2.22  pyhd8ed1ab_0        conda-forge         "
# [262] "  + pysocks                         1.7.1  pyha2e5f31_6        conda-forge         "
# [263] "  + ruamel.yaml.clib                0.2.8  py312h98912ed_0     conda-forge         "
# [264] "  + setuptools                     74.1.2  pyhd8ed1ab_0        conda-forge         "
# [265] "  + truststore                      0.9.2  pyhd8ed1ab_0        conda-forge         "
# [266] "  + wheel                          0.44.0  pyhd8ed1ab_0        conda-forge         "
# [267] "  + cffi                           1.17.1  py312h06ac9bb_0     conda-forge         "
# [268] "  + h2                              4.1.0  pyhd8ed1ab_0        conda-forge         "
# [269] "  + jsonpatch                        1.33  pyhd8ed1ab_0        conda-forge         "
# [270] "  + libmambapy                      1.5.9  py312h7fb9e8e_0     conda-forge         "
# [271] "  + pip                              24.2  pyh8b19718_1        conda-forge         "
# [272] "  + ruamel.yaml                    0.18.6  py312h98912ed_0     conda-forge         "
# [273] "  + tqdm                           4.66.5  pyhd8ed1ab_0        conda-forge         "
# [274] "  + zstandard                      0.23.0  py312hef9b889_1     conda-forge         "
# [275] "  + conda-package-streaming        0.10.0  pyhd8ed1ab_0        conda-forge         "
# [276] "  + urllib3                         2.2.3  pyhd8ed1ab_0        conda-forge         "
# [277] "  + conda-package-handling          2.3.0  pyh7900ff3_0        conda-forge         "
# [278] "  + requests                       2.32.3  pyhd8ed1ab_0        conda-forge         "
# [279] "  + conda                          24.7.1  py312h7900ff3_0     conda-forge         "
# [280] "  + conda-libmamba-solver          24.7.0  pyhd8ed1ab_0        conda-forge         "
# [281] "  + mamba                           1.5.9  py312h9460a1c_0     conda-forge         "
# [282] ""
# [283] "  Summary:"
# [284] ""
# [285] "  Install: 85 packages"
# [286] ""
# [287] "  Total download: 0 B"
# [288] ""
# [289] "─────────────────────────────────────────────────────────────────────────────────────"
# [290] ""
# [291] ""
# [292] ""
# [293] "Transaction starting"
# [294] ""
# [295] "Transaction finished"
# [296] ""
# [297] "To activate this environment, use:"
# [298] ""
# [299] "    micromamba activate /home/ec2-user/miniforge"
# [300] ""
# [301] "Or to execute a single command in this environment, use:"
# [302] ""
# [303] "    micromamba run -p /home/ec2-user/miniforge mycommand"
# [304] ""
# [305] "installation finished."

# %%
# Install gsutil and dependencies using mamba
system('mamba install -y -c conda-forge -c bioconda gsutil', intern = TRUE)
# Out:
#  [1] "Transaction"
#  [2] ""
#  [3] "  Prefix: /home/ec2-user/anaconda3/envs/R"
#  [4] ""
#  [5] "  Updating specs:"
#  [6] ""
#  [7] "   - gsutil"
#  [8] "   - ca-certificates"
#  [9] "   - certifi"
# [10] "   - openssl"
# [11] ""
# [12] ""
# [13] "  Package                   Version  Build               Channel          Size"
# [14] "────────────────────────────────────────────────────────────────────────────────"
# [15] "  Install:"
# [16] "────────────────────────────────────────────────────────────────────────────────"
# [17] ""
# [18] "  + boto                     2.49.0  py_0                conda-forge     858kB"
# [19] "  + pyu2f                     0.1.5  pyhd8ed1ab_0        conda-forge      32kB"
# [20] "  + argcomplete               3.5.1  pyhd8ed1ab_0        conda-forge      41kB"
# [21] "  + fasteners                0.17.3  pyhd8ed1ab_0        conda-forge      20kB"
# [22] "  + monotonic                   1.5  pyhd8ed1ab_1        conda-forge      13kB"
# [23] "  + retry_decorator           1.1.1  pyh9f0ad1d_0        conda-forge       7kB"
# [24] "  + cachetools                5.5.0  pyhd8ed1ab_0        conda-forge      15kB"
# [25] "  + pyasn1                    0.6.1  pyhd8ed1ab_1        conda-forge      62kB"
# [26] "  + pyparsing                 3.1.4  pyhd8ed1ab_0        conda-forge      90kB"
# [27] "  + attrs                    24.2.0  pyh71513ae_0        conda-forge      56kB"
# [28] "  + aiohappyeyeballs          2.4.3  pyhd8ed1ab_0        conda-forge      19kB"
# [29] "  + google-reauth             0.1.1  pyhd3deb0d_0        conda-forge      18kB"
# [30] "  + pyasn1-modules            0.4.1  pyhd8ed1ab_0        conda-forge      96kB"
# [31] "  + rsa                       4.7.2  pyh44b312d_0        conda-forge      28kB"
# [32] "  + httplib2                 0.20.4  pyhd8ed1ab_0        conda-forge      98kB"
# [33] "  + oauth2client              4.1.3  py_0                conda-forge      67kB"
# [34] "  + google-apitools          0.5.32  pyhd8ed1ab_0        conda-forge      96kB"
# [35] "  + crcmod                      1.7  py311h9ecbd09_1011  conda-forge      42kB"
# [36] "  + frozenlist                1.4.1  py311h9ecbd09_1     conda-forge      60kB"
# [37] "  + multidict                 6.1.0  py311h9ecbd09_0     conda-forge      63kB"
# [38] "  + cryptography             43.0.1  py311hafd3f86_0     conda-forge       2MB"
# [39] "  + propcache                 0.2.0  py311h9ecbd09_2     conda-forge      54kB"
# [40] "  + yarl                     1.14.0  py311h9ecbd09_0     conda-forge     139kB"
# [41] "  + aiosignal                 1.3.1  pyhd8ed1ab_0        conda-forge      13kB"
# [42] "  + pyopenssl                24.2.1  pyhd8ed1ab_2        conda-forge     128kB"
# [43] "  + aiohttp                  3.10.9  py311h9ecbd09_0     conda-forge     842kB"
# [44] "  + google-auth              2.17.0  pyh1a96a4e_0        conda-forge      99kB"
# [45] "  + google-auth-httplib2      0.2.0  pyhd8ed1ab_0        conda-forge      15kB"
# [46] "  + gcs-oauth2-boto-plugin      3.2  pyhd8ed1ab_0        conda-forge      30kB"
# [47] "  + gsutil                     5.30  pyhd8ed1ab_0        conda-forge       2MB"
# [48] ""
# [49] "  Summary:"
# [50] ""
# [51] "  Install: 30 packages"
# [52] ""
# [53] "  Total download: 7MB"
# [54] ""
# [55] "────────────────────────────────────────────────────────────────────────────────"
# [56] ""
# [57] ""
# [58] ""
# [59] "Looking for: ['gsutil']"
# [60] ""
# [61] ""
# [62] "Pinned packages:"
# [63] "  - python 3.11.*"
# [64] ""
# [65] ""
# [66] ""
# [67] "Downloading and Extracting Packages: ...working... done"
# [68] "Preparing transaction: ...working... done"
# [69] "Verifying transaction: ...working... done"
# [70] "Executing transaction: ...working... done"

# %% [markdown]
# ### STEP 1: Library Installation
#
# First install the R packages that will be used. <strong>This installation may take around 30 minutes.</strong>

# %%
# Install BiocManager if not installed
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

# Set repositories
options(repos = BiocManager::repositories())

# Install Bioconductor packages
BiocManager::install(c("ComplexHeatmap", "DESeq2", "EnhancedVolcano"), force = TRUE)

# Install CRAN packages
install.packages(c("dplyr", "pheatmap", "ggrepel", "ggfortify"), dependencies = TRUE)
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     BioCsoft: https://bioconductor.org/packages/3.19/bioc
#     BioCann: https://bioconductor.org/packages/3.19/data/annotation
#     BioCexp: https://bioconductor.org/packages/3.19/data/experiment
#     BioCworkflows: https://bioconductor.org/packages/3.19/workflows
#     BioCbooks: https://bioconductor.org/packages/3.19/books
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.19 (BiocManager 1.30.25), R 4.4.1 (2024-06-14)
#
# Installing package(s) 'BiocVersion', 'ComplexHeatmap', 'DESeq2',
#   'EnhancedVolcano'
#
# also installing the dependencies ‘UCSC.utils’, ‘GenomeInfoDbData’, ‘zlibbioc’, ‘abind’, ‘SparseArray’, ‘lambda.r’, ‘futile.options’, ‘rjson’, ‘GenomeInfoDb’, ‘XVector’, ‘S4Arrays’, ‘DelayedArray’, ‘futile.logger’, ‘snow’, ‘BH’, ‘circlize’, ‘GetoptLong’, ‘clue’, ‘GlobalOptions’, ‘IRanges’, ‘matrixStats’, ‘doParallel’, ‘S4Vectors’, ‘GenomicRanges’, ‘SummarizedExperiment’, ‘BiocGenerics’, ‘Biobase’, ‘BiocParallel’, ‘locfit’, ‘MatrixGenerics’, ‘RcppArmadillo’, ‘ggrepel’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Old packages: 'curl', 'data.table', 'evaluate', 'MASS', 'Matrix', 'nlme', 'ps'
#
# also installing the dependencies ‘credentials’, ‘zip’, ‘gitcreds’, ‘ini’, ‘curl’, ‘rbibutils’, ‘bitops’, ‘gert’, ‘gh’, ‘whisker’, ‘downlit’, ‘httr2’, ‘xopen’, ‘brew’, ‘gss’, ‘stabledist’, ‘gbutils’, ‘Rdpack’, ‘gtools’, ‘caTools’, ‘RSpectra’, ‘profmem’, ‘rex’, ‘plogr’, ‘brio’, ‘desc’, ‘pkgload’, ‘praise’, ‘waldo’, ‘diffobj’, ‘polynom’, ‘usethis’, ‘miniUI’, ‘pkgbuild’, ‘pkgdown’, ‘profvis’, ‘rcmdcheck’, ‘remotes’, ‘roxygen2’, ‘rversions’, ‘sessioninfo’, ‘urlchecker’, ‘beeswarm’, ‘vipor’, ‘fBasics’, ‘fastICA’, ‘cvar’, ‘fracdiff’, ‘lmtest’, ‘urca’, ‘cyclocomp’, ‘xmlparsedata’, ‘terra’, ‘gplots’, ‘sandwich’, ‘quadprog’, ‘rARPACK’, ‘bench’, ‘covr’, ‘Lahman’, ‘microbenchmark’, ‘nycflights13’, ‘RMySQL’, ‘RPostgreSQL’, ‘RSQLite’, ‘testthat’, ‘svglite’, ‘vdiffr’, ‘gridExtra’, ‘ggpp’, ‘patchwork’, ‘devtools’, ‘prettydoc’, ‘ggbeeswarm’, ‘changepoint’, ‘fGarch’, ‘forecast’, ‘KFAS’, ‘lintr’, ‘mapdata’, ‘markdown’, ‘MSwM’, ‘raster’, ‘ROCR’, ‘sp’, ‘strucchange’, ‘timeSeries’, ‘tseries’, ‘vars’, ‘lfda’
#
#
# Warning message in install.packages(c("dplyr", "pheatmap", "ggrepel", "ggfortify"), :
# “installation of package ‘terra’ had non-zero exit status”
# Warning message in install.packages(c("dplyr", "pheatmap", "ggrepel", "ggfortify"), :
# “installation of package ‘RMySQL’ had non-zero exit status”
# Warning message in install.packages(c("dplyr", "pheatmap", "ggrepel", "ggfortify"), :
# “installation of package ‘RPostgreSQL’ had non-zero exit status”
# Warning message in install.packages(c("dplyr", "pheatmap", "ggrepel", "ggfortify"), :
# “installation of package ‘raster’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# Load libraries
library(DESeq2)
library(dplyr)
library(ComplexHeatmap)
library(EnhancedVolcano)
library(ggplot2)
library(ggrepel)
library(ggfortify)
# Out:
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomicRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: grid
#
# ========================================
# ComplexHeatmap version 2.20.0
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite either one:
# - Gu, Z. Complex Heatmap Visualization. iMeta 2022.
# - Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#     genomic data. Bioinformatics 2016.
#
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
#
# Loading required package: ggplot2
#
# Loading required package: ggrepel

# %% [markdown]
# ### STEP 2: Reading in Data
#
# This step retrieve the Merged Read counts from all samples of Bioproject PRJNA892075, and the feature table, from S3 Bucket. This step involves reformatting or adjusting the data.
#
# To make things easier, we created a matrix, or a table, of just our read-count data -- excluding the non-numerical metadata columns. This makes it easy for us to feed this table into the deseq2 tool later on.
#
# Additionally, later on we will use normalization involving logarithms. So, to prevent errors, we will replace all readcount values of '0' in our data, with '1'. This will change the data only slightly, and will prevent these zeroes from causing an 'undefined' or 'N/A' math error in the logarithm normalization step.

# %%
# Check if the directories exist before creating them
if (!dir.exists("data/gene_counts")) {
  dir.create("data/gene_counts", recursive = TRUE)
}

if (!dir.exists("data/reference")) {
  dir.create("data/reference", recursive = TRUE)
}

# Path to the gene counts file
system("wget -P data/gene_counts/ https://sra-data-athena.s3.amazonaws.com/readcounts/merged_gene_counts_celegans.txt")
system("wget -P data/reference/ https://sra-data-athena.s3.amazonaws.com/reference/celegans_feature_table.txt")

# Define the file paths
counts_file <- "data/gene_counts/merged_gene_counts_celegans.txt"
feature_table <- "data/reference/celegans_feature_table.txt"

# %%
#read-in the raw gene count file to a dataframe variable we named 'read_counts'
read_counts <- read.table('data/gene_counts/merged_gene_counts_celegans.txt',head=TRUE)

#amount of columns the dataframe has
cols = ncol(read_counts)

#assign the numerical read counts to a matrix variable we named 'rnaseqMatrix'
rnaseqMatrix <- round(read_counts[,c(2:cols)])

#label the rownames of this matrix with the rowname column from the gene count dataframe.
rownames(rnaseqMatrix) <- read_counts[,1]

head(rnaseqMatrix)
# Out:
#                GSM4478068 GSM4478070 GSM4478072 GSM4478074 GSM4478076
# WBGene00000001 1548       1324       1601       1300       1363
# WBGene00000002  272        205        266        271        210
# WBGene00000003  177        124        139        224         95
# WBGene00000004  370        281        341        356        235
# WBGene00000005  125         88        101         72         97
# WBGene00000006  482        384        398        362        195
#                GSM4478078
# WBGene00000001 2217
# WBGene00000002  602
# WBGene00000003  316
# WBGene00000004  386
# WBGene00000005  236
# WBGene00000006  357

# %% [markdown]
# ### STEP 3: Specifying Experimental Design
#
# Next specify the experimental design.
#
# The deseq2 tool will later use this design to group samples together, and output information about the statistical differences in gene expression between these specified groups.

# %%
# define the sample experimental design, in this case 3 control and 3 cortisol infected samples
samples_treatment <- data.frame(matrix(c(rep("glh1",3),rep("wt",3)),ncol=1))
samples_ID <- data.frame(matrix(colnames(rnaseqMatrix),ncol=1))
samples <- cbind(samples_ID,samples_treatment)
names(samples) <- c("ID","Treatment")
rownames(samples) <- samples[,1]

print("An example of how a deseq2 experimental design table might look.")
samples
# Out:
# [1] "An example of how a deseq2 experimental design table might look."
#            ID         Treatment
# GSM4478068 GSM4478068 glh1
# GSM4478070 GSM4478070 glh1
# GSM4478072 GSM4478072 glh1
# GSM4478074 GSM4478074 wt
# GSM4478076 GSM4478076 wt
# GSM4478078 GSM4478078 wt

# %% [markdown]
# ### STEP 4: Creating Deseq2 Object
#
# Now use the treatment design matrix in combination with the readcount matrix to create a deseq2 object.
#
# Once created, this is also a good opportunity to filter out lowly expresseed genes, and to inspect the pre-normalized data using pairwise comparison plots. These example plots, the pairwise plot and boxplot, can be used to examine gene expression distributions and highlight outliers.
#
# Finally, the deseq2 analysis can be run on the deseq2 object.

# %%
#Create the DEseq2DataSet object
deseq2Data <- DESeqDataSetFromMatrix(countData = rnaseqMatrix, colData = samples, design = ~ Treatment)

# Perform pre-filtering of the data (deseq2 also automatically does this, but can this can increase speed)
deseq2Data <- deseq2Data[rowSums(counts(deseq2Data)) > 10, ]

# Inspect pre-normalized data 
pairs(log2((counts(deseq2Data)+1)))
boxplot(log2((counts(deseq2Data)+1)))

# Run pipeline for differential expression steps
deseq2Data <- DESeq(deseq2Data)
# Out:
# converting counts to integer mode
#
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”
# plot without title
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
# plot without title

# %% [markdown]
# ### STEP 5: Normalize Data
#
# DESeq2 automatically normalizes data in the DESeq() step using a method called median of ratios. For our own downstream analysis we can pick from several different normalization methods. As an example, here we use rlog transformation, or regularized log transformation to normalize data. This method is similar to log normalization, but includes a 'shrinkage' estimator to attempt to shrink the variance of the log-transformed data. More information for this and other normalization methods can be found in the DESeq2 documentation.
#
# Normalization of gene readcounts across samples will help to minimize sample variation noise and ensure more accurate comparisons. Looking at normalized plots can be an easy way to look out for any obvious inconsistencies or errors in the sample data.

# %%
#perform rlog normalization on deseq2 object
rld <- rlog(deseq2Data, blind=FALSE)

#a handy variable so we can easily reference the rlog genecount matrix in the future, as deseq objects contain many tables of data.
rlogcounts <- assay(rld)
rownames(rlogcounts) <- rownames(deseq2Data)

head(rlogcounts)
# Out:
#                GSM4478068 GSM4478070 GSM4478072 GSM4478074 GSM4478076
# WBGene00000001 10.471052  10.534557  10.593609  10.436254  10.737009
# WBGene00000002  8.007782   7.958714   8.066606   8.121828   8.126370
# WBGene00000003  7.332669   7.233280   7.220785   7.632469   7.171598
# WBGene00000004  8.346631   8.300032   8.355698   8.434613   8.298534
# WBGene00000005  6.796947   6.709852   6.714344   6.530892   6.898095
# WBGene00000006  8.631254   8.625155   8.540513   8.496950   8.190702
#                GSM4478078
# WBGene00000001 10.682387
# WBGene00000002  8.587119
# WBGene00000003  7.687766
# WBGene00000004  8.258144
# WBGene00000005  7.169420
# WBGene00000006  8.238437

# %% [markdown]
# Normalization of data can is often verified by inspecting by various plots, such as histograms (these typically follow a negative binomial distribution, as shown below):

# %%
hist(rlogcounts)
# Out:
# Plot with title “Histogram of rlogcounts”

# %% [markdown]
# Boxplots:

# %%
boxplot(rlogcounts)
# Out:
# plot without title

# %% [markdown]
# Or pairwise comparison plots. Notice how sample groups can be visualized just by looking at the pairwise plot.

# %%
pairs(rlogcounts)
# Out:
# plot without title

# %% [markdown]
# Compare the plots of the pre-normalized and normalized data to see the effect of normalization.
#
# Notice how the samples in the box plot, and in-group samples in the pair plots display similar distributions.
#
# Looking at normalized plots can be an easy way to look out for any obvious inconsistencies or errors in the sample data.

# %% [markdown]
# ### STEP 6: PCA Plot
#
# We can now begin to produce plots to further analyze the differences between groups.
#
# PCA plots can be an effective way to visualize variation within and between sample sets.

# %%
pca_counts <- prcomp(t(rlogcounts))
autoplot(pca_counts, data = samples, colour="Treatment", size=6)
# Out:
# plot without title

# %% [markdown]
# Plots can be output as above, or also saved as pdf or image files, as below. Try to navigate and click to the created file, after you run the code.
#
# Tiff files can also be created this way.

# %%
pdf("data/gene_counts/PCA_Plot.pdf")
autoplot(pca_counts, data = samples, colour="Treatment", size=6)
dev.off()

tiff("data/gene_counts/PCA_Plot.tiff")
autoplot(pca_counts, data = samples, colour="Treatment", size=6)
dev.off()
# Out:
# pdf
#   2
# pdf
#   2

# %% [markdown]
# ### STEP 7: Contrast Comparisons
#
# Contrast comparisons between two treatment groups can be performed using the deseq2 tool to identify differentially up and down regulated genes.
#
# Using R, these results can be summarized, reordered, and/or trimmed.
#
# Differentially expressed genes are typically quantified as those genes which have an adjusted P value of below 0.05. An adjusted P value is also sometimes referred to as a false discovery rate, or FDR. In the below, there are 1357 differentially expressed genes. For the sake of reducing the amount of differentially expressed genes, to make analyses easier, these could also be further refined by introducing a threshold based on fold-change. DEseq2 uses the Wald and Benjamini-Hochberg tests for determining P and Adjusted P values, respectively. More information on this can be found in the DEseq2 documentation.

# %%
#Output the results of comparing WT and BPs_lysogen group
res_glh1_wt <- results(deseq2Data, contrast=c("Treatment","glh1","wt"))
summary(res_glh1_wt)
print("Number of genes under a p value of 0.05")
sum(res_glh1_wt$pvalue < 0.05, na.rm=TRUE)
print("Number of genes under a p adjusted value of 0.05")
sum(res_glh1_wt$padj < 0.05, na.rm=TRUE)


#deseq2 optionally output some padj values as 'NA' when genecounts meet certain criteria
#that criteria can be found here: https://bioconductor.org/packages/release/bioc/vignettes/DESeq2/inst/doc/DESeq2.html#pvaluesNA
#for practical uses, one could replace the NA values with '1', essentially NA values not significant.
res_glh1_wt$padj[is.na(res_glh1_wt$padj)] <- 1
# Out:
# out of 18586 with nonzero total read count
# adjusted p-value < 0.1
# LFC > 0 (up)       : 1606, 8.6%
# LFC < 0 (down)     : 1754, 9.4%
# outliers [1]       : 27, 0.15%
# low counts [2]     : 2162, 12%
# (mean count < 8)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results
#
# [1] "Number of genes under a p value of 0.05"
# [1] 4669
# [1] "Number of genes under a p adjusted value of 0.05"
# [1] 2384

# %% [markdown]
# ### STEP 8: Annotating and Exporting Results
#
# These differentially expressed genes can be annotated and exported.
#
# Combining gene counts with gene annotation isn't always simple, and will vary heavily depending on the annotation file itself.
#
# For example, when merging genecounts by 'gene id' with feature tables from NCBI's assembly database, its very common to have duplicate rows, as a single 'gene id' may match to multiple features.
#
# Depending on how you want to use your annotated results, you may decide to further reformat your table in whatever suits your further analysis best, for instance by downloading and using a spreadsheet editor.
#
# Because the transcript table for m chelonae we have here is so simple, and contains essentially only one 'CDS' or '..RNA' feature for every gene identifier we are using, it is easy for us to reformat it here in the way we want just using R code. However, it is important to note that, again, this is very often not the case, and reformatting will vary depending on both the annotation file itself, and what that annotation file will be used for.

# %%
head (annotation)
# Out:
#
# 1 new("standardGeneric", .Data = function (object, ...)
# 2 standardGeneric("annotation"), generic = structure("annotation", package = "BiocGenerics"),
# 3     package = "BiocGenerics", group = list(), valueClass = character(0),
# 4     signature = "object", default = NULL, skeleton = (function (object,
# 5         ...)
# 6     stop(gettextf("invalid call in method dispatch to '%s' (no default method)",

# %%
# Read the annotation file
annotation <- read.table("data/gene_counts/merged_gene_counts_celegans.txt", header=TRUE, sep='\t', quote="\"", comment.char = "")

# Convert DESeq2 results to a data frame
results <- data.frame(res_glh1_wt)

# Merge annotation with DESeq2 results
results.annot <- merge(results, annotation, by.x="row.names", by.y="Name", all.x=TRUE)

# If needed, filter out "gene" rows (you can skip this if no such column exists)
# results.annot <- results.annot[annotation$X..feature != 'gene',]

# Rename the first column to 'locus_tag'
colnames(results.annot)[1] <- 'locus_tag'

# Write out the annotated results
write.table(results.annot, "data/gene_counts/glh1_wt_DESeq2_annot.txt", row.names=FALSE, sep="\t")

# View the first few rows of the annotated data
head(results.annot)
# Out:
#   locus_tag      baseMean  log2FoldChange lfcSE     stat        pvalue
# 1 WBGene00000001 1534.6310 -0.135149737   0.1759877 -0.76795005 0.44251686
# 2 WBGene00000002  289.9707 -0.487300439   0.2520087 -1.93366508 0.05315432
# 3 WBGene00000003  170.6836 -0.480097498   0.2831047 -1.69583041 0.08991800
# 4 WBGene00000004  322.8557  0.002862122   0.1834757  0.01559946 0.98755393
# 5 WBGene00000005  114.6859 -0.324831489   0.3361541 -0.96631706 0.33388555
# 6 WBGene00000006  356.0957  0.459959467   0.2057186  2.23586735 0.02536046
#   padj      GSM4478068 GSM4478070 GSM4478072 GSM4478074 GSM4478076 GSM4478078
# 1 0.6660683 1547.66    1323.54    1600.99    1299.79    1362.61    2217.35
# 2 0.1858757  272.00     205.00     266.00     271.00     210.00     602.00
# 3 0.2605842  177.00     124.00     139.00     224.00      95.00     316.00
# 4 0.9944069  370.00     281.00     341.00     356.00     235.00     386.00
# 5 0.5696050  125.00      88.00     101.00      72.00      97.00     236.00
# 6 0.1154457  482.00     384.00     398.00     362.00     195.00     357.00

# %% [markdown]
# ### STEP 9: More Plots and Clustering Data
#
# Finally, although several other different kind of analysis can be done, it is common to plot the results of differential gene expression analysis in forms such as volcano, MA, and heatmaps. These plots help one to further examine the output list of differentially expressed genes in different ways, and potentially identify or further investigate candidate gene(s).

# %%
#volcano and ma plots can be used to visualize significant differences in gene expression
results_volc_df <- results.annot
EnhancedVolcano(results_volc_df,
    lab = results_volc_df[,1],
    x = 'log2FoldChange',
    y = 'padj')

#ma plot
plotMA(res_glh1_wt)


#heatmaps can used to look at clustering and expression of various gene lists.
filtered_res <- results.annot %>% filter(padj < 0.05)
filtered_res_counts <- subset(rlogcounts, rownames(rlogcounts) %in% filtered_res[,1])
filtered_res_counts = t(scale(t(filtered_res_counts)))
Heatmap(filtered_res_counts[1:50,], name = "Z-Score", row_names_gp = gpar(fontsize = 8))
# Out:
# plot without title
# Plot with title “”
