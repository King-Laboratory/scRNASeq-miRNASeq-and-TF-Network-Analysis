# %% [markdown]
# # RNA-Seq Analysis Training Demo

# %% [markdown]
# ## Overview

# %% [markdown]
# This tutorial will show you the following workflow that is used to generate the list of differentially expressed genes. Running the code in this tutorial should take approximately 15 minutes.
#
# This overflow centers roughly around the useage of the deseq2 package. Documentation for this package can be found here: https://bioconductor.org/packages/release/bioc/vignettes/DESeq2/inst/doc/DESeq2.html
#
# ![RNA-Seq workflow](images/count-workflow.png)

# %%
# Install Mambaforge using curl and bash
system('curl -L -O https://github.com/conda-forge/miniforge/releases/latest/download/Mambaforge-Linux-x86_64.sh', intern = TRUE)
system('bash Mambaforge-Linux-x86_64.sh -b -u -p $HOME/mambaforge', intern = TRUE)

# Add mambaforge bin to the system path
Sys.setenv(PATH = paste(Sys.getenv("HOME"), "/mambaforge/bin:", Sys.getenv("PATH"), sep = ""))
# Out:
# character(0)
#   [1] "PREFIX=/home/ec2-user/mambaforge"
#   [2] ""
#   [3] "Transaction"
#   [4] ""
#   [5] "  Prefix: /home/ec2-user/mambaforge/envs/_virtual_specs_checks"
#   [6] ""
#   [7] "  All requested packages already installed"
#   [8] ""
#   [9] "Dry run. Not executing the transaction."
#  [10] "Unpacking payload ..."
#  [11] "Extracting _libgcc_mutex-0.1-conda_forge.tar.bz2"
#  [12] "Extracting ca-certificates-2024.8.30-hbcca054_0.conda"
#  [13] "Extracting ld_impl_linux-64-2.40-hf3520f5_7.conda"
#  [14] "Extracting pybind11-abi-4-hd8ed1ab_3.tar.bz2"
#  [15] "Extracting python_abi-3.12-5_cp312.conda"
#  [16] "Extracting tzdata-2024a-h8827d51_1.conda"
#  [17] "Extracting libgomp-14.1.0-h77fa898_1.conda"
#  [18] "Extracting _openmp_mutex-4.5-2_gnu.tar.bz2"
#  [19] "Extracting libgcc-14.1.0-h77fa898_1.conda"
#  [20] "Extracting libgcc-ng-14.1.0-h69a702a_1.conda"
#  [21] "Extracting libstdcxx-14.1.0-hc0a3c3a_1.conda"
#  [22] "Extracting bzip2-1.0.8-h4bc722e_7.conda"
#  [23] "Extracting c-ares-1.32.3-h4bc722e_0.conda"
#  [24] "Extracting keyutils-1.6.1-h166bdaf_0.tar.bz2"
#  [25] "Extracting libev-4.33-hd590300_2.conda"
#  [26] "Extracting libexpat-2.6.2-h59595ed_0.conda"
#  [27] "Extracting libffi-3.4.2-h7f98852_5.tar.bz2"
#  [28] "Extracting libiconv-1.17-hd590300_2.conda"
#  [29] "Extracting libnsl-2.0.1-hd590300_0.conda"
#  [30] "Extracting libstdcxx-ng-14.1.0-h4852527_1.conda"
#  [31] "Extracting libuuid-2.38.1-h0b41bf4_0.conda"
#  [32] "Extracting libxcrypt-4.4.36-hd590300_1.conda"
#  [33] "Extracting libzlib-1.3.1-h4ab18f5_1.conda"
#  [34] "Extracting lzo-2.10-hd590300_1001.conda"
#  [35] "Extracting ncurses-6.5-he02047a_1.conda"
#  [36] "Extracting openssl-3.3.1-hb9d3cd8_3.conda"
#  [37] "Extracting reproc-14.2.4.post0-hd590300_1.conda"
#  [38] "Extracting xz-5.2.6-h166bdaf_0.tar.bz2"
#  [39] "Extracting fmt-10.2.1-h00ab1b0_0.conda"
#  [40] "Extracting icu-75.1-he02047a_0.conda"
#  [41] "Extracting libedit-3.1.20191231-he28a2e2_2.tar.bz2"
#  [42] "Extracting libnghttp2-1.58.0-h47da74e_1.conda"
#  [43] "Extracting libsolv-0.7.30-h3509ff9_0.conda"
#  [44] "Extracting libsqlite-3.46.1-hadc24fc_0.conda"
#  [45] "Extracting libssh2-1.11.0-h0841786_0.conda"
#  [46] "Extracting lz4-c-1.9.4-hcb278e6_0.conda"
#  [47] "Extracting readline-8.2-h8228510_1.conda"
#  [48] "Extracting reproc-cpp-14.2.4.post0-h59595ed_1.conda"
#  [49] "Extracting tk-8.6.13-noxft_h4845f30_101.conda"
#  [50] "Extracting yaml-cpp-0.8.0-h59595ed_0.conda"
#  [51] "Extracting zstd-1.5.6-ha6fb4c9_0.conda"
#  [52] "Extracting krb5-1.21.3-h659f571_0.conda"
#  [53] "Extracting libxml2-2.12.7-he7c6b58_4.conda"
#  [54] "Extracting python-3.12.5-h2ad013b_0_cpython.conda"
#  [55] "Extracting libarchive-3.7.4-hfca40fe_0.conda"
#  [56] "Extracting libcurl-8.9.1-hdb1bdb2_0.conda"
#  [57] "Extracting menuinst-2.1.2-py312h7900ff3_1.conda"
#  [58] "Extracting archspec-0.2.3-pyhd8ed1ab_0.conda"
#  [59] "Extracting boltons-24.0.0-pyhd8ed1ab_0.conda"
#  [60] "Extracting brotli-python-1.1.0-py312h2ec8cdc_2.conda"
#  [61] "Extracting certifi-2024.8.30-pyhd8ed1ab_0.conda"
#  [62] "Extracting charset-normalizer-3.3.2-pyhd8ed1ab_0.conda"
#  [63] "Extracting colorama-0.4.6-pyhd8ed1ab_0.tar.bz2"
#  [64] "Extracting distro-1.9.0-pyhd8ed1ab_0.conda"
#  [65] "Extracting frozendict-2.4.4-py312h9a8786e_0.conda"
#  [66] "Extracting hpack-4.0.0-pyh9f0ad1d_0.tar.bz2"
#  [67] "Extracting hyperframe-6.0.1-pyhd8ed1ab_0.tar.bz2"
#  [68] "Extracting idna-3.8-pyhd8ed1ab_0.conda"
#  [69] "Extracting jsonpointer-3.0.0-py312h7900ff3_1.conda"
#  [70] "Extracting libmamba-1.5.9-h4cc3d14_0.conda"
#  [71] "Extracting packaging-24.1-pyhd8ed1ab_0.conda"
#  [72] "Extracting platformdirs-4.2.2-pyhd8ed1ab_0.conda"
#  [73] "Extracting pluggy-1.5.0-pyhd8ed1ab_0.conda"
#  [74] "Extracting pycosat-0.6.6-py312h98912ed_0.conda"
#  [75] "Extracting pycparser-2.22-pyhd8ed1ab_0.conda"
#  [76] "Extracting pysocks-1.7.1-pyha2e5f31_6.tar.bz2"
#  [77] "Extracting ruamel.yaml.clib-0.2.8-py312h98912ed_0.conda"
#  [78] "Extracting setuptools-73.0.1-pyhd8ed1ab_0.conda"
#  [79] "Extracting truststore-0.9.2-pyhd8ed1ab_0.conda"
#  [80] "Extracting wheel-0.44.0-pyhd8ed1ab_0.conda"
#  [81] "Extracting cffi-1.17.0-py312h06ac9bb_1.conda"
#  [82] "Extracting h2-4.1.0-pyhd8ed1ab_0.tar.bz2"
#  [83] "Extracting jsonpatch-1.33-pyhd8ed1ab_0.conda"
#  [84] "Extracting libmambapy-1.5.9-py312h7fb9e8e_0.conda"
#  [85] "Extracting pip-24.2-pyh8b19718_1.conda"
#  [86] "Extracting ruamel.yaml-0.18.6-py312h98912ed_0.conda"
#  [87] "Extracting tqdm-4.66.5-pyhd8ed1ab_0.conda"
#  [88] "Extracting zstandard-0.23.0-py312hef9b889_1.conda"
#  [89] "Extracting conda-package-streaming-0.10.0-pyhd8ed1ab_0.conda"
#  [90] "Extracting urllib3-2.2.2-pyhd8ed1ab_1.conda"
#  [91] "Extracting conda-package-handling-2.3.0-pyh7900ff3_0.conda"
#  [92] "Extracting requests-2.32.3-pyhd8ed1ab_0.conda"
#  [93] "Extracting conda-24.7.1-py312h7900ff3_0.conda"
#  [94] "Extracting conda-libmamba-solver-24.7.0-pyhd8ed1ab_0.conda"
#  [95] "Extracting mamba-1.5.9-py312h9460a1c_0.conda"
#  [96] "!!!!!! Mambaforge is now deprecated !!!!!"
#  [97] "Future Miniforge releases will NOT build Mambaforge installers."
#  [98] "We advise you switch to Miniforge at your earliest convenience."
#  [99] "More details at https://conda-forge.org/news/2024/07/29/sunsetting-mambaforge/."
# [100] "If you are unable to switch to Miniforge, you may pin your installer version to one found in "
# [101] "https://github.com/conda-forge/miniforge/releases/tag/24.5.0-1"
# [102] "or if you lack the system requirements (Linux glibc >= 2.17, or macOS + x86-64bit >= 10.13)"
# [103] "you may pin your installer to one older version found in "
# [104] "https://github.com/conda-forge/miniforge/releases/tag/24.3.0-0"
# [105] ""
# [106] "Installing base environment..."
# [107] ""
# [108] "Transaction"
# [109] ""
# [110] "  Prefix: /home/ec2-user/mambaforge"
# [111] ""
# [112] "  Updating specs:"
# [113] ""
# [114] "   - conda-forge/linux-64::_libgcc_mutex==0.1=conda_forge[md5=d7c89558ba9fa0495403155b64376d81]"
# [115] "   - conda-forge/linux-64::ca-certificates==2024.8.30=hbcca054_0[md5=c27d1c142233b5bc9ca570c6e2e0c244]"
# [116] "   - conda-forge/linux-64::ld_impl_linux-64==2.40=hf3520f5_7[md5=b80f2f396ca2c28b8c14c437a4ed1e74]"
# [117] "   - conda-forge/noarch::pybind11-abi==4=hd8ed1ab_3[md5=878f923dd6acc8aeb47a75da6c4098be]"
# [118] "   - conda-forge/linux-64::python_abi==3.12=5_cp312[md5=0424ae29b104430108f5218a66db7260]"
# [119] "   - conda-forge/noarch::tzdata==2024a=h8827d51_1[md5=8bfdead4e0fff0383ae4c9c50d0531bd]"
# [120] "   - conda-forge/linux-64::libgomp==14.1.0=h77fa898_1[md5=23c255b008c4f2ae008f81edcabaca89]"
# [121] "   - conda-forge/linux-64::_openmp_mutex==4.5=2_gnu[md5=73aaf86a425cc6e73fcf236a5a46396d]"
# [122] "   - conda-forge/linux-64::libgcc==14.1.0=h77fa898_1[md5=002ef4463dd1e2b44a94a4ace468f5d2]"
# [123] "   - conda-forge/linux-64::libgcc-ng==14.1.0=h69a702a_1[md5=1efc0ad219877a73ef977af7dbb51f17]"
# [124] "   - conda-forge/linux-64::libstdcxx==14.1.0=hc0a3c3a_1[md5=9dbb9699ea467983ba8a4ba89b08b066]"
# [125] "   - conda-forge/linux-64::bzip2==1.0.8=h4bc722e_7[md5=62ee74e96c5ebb0af99386de58cf9553]"
# [126] "   - conda-forge/linux-64::c-ares==1.32.3=h4bc722e_0[md5=7624e34ee6baebfc80d67bac76cc9d9d]"
# [127] "   - conda-forge/linux-64::keyutils==1.6.1=h166bdaf_0[md5=30186d27e2c9fa62b45fb1476b7200e3]"
# [128] "   - conda-forge/linux-64::libev==4.33=hd590300_2[md5=172bf1cd1ff8629f2b1179945ed45055]"
# [129] "   - conda-forge/linux-64::libexpat==2.6.2=h59595ed_0[md5=e7ba12deb7020dd080c6c70e7b6f6a3d]"
# [130] "   - conda-forge/linux-64::libffi==3.4.2=h7f98852_5[md5=d645c6d2ac96843a2bfaccd2d62b3ac3]"
# [131] "   - conda-forge/linux-64::libiconv==1.17=hd590300_2[md5=d66573916ffcf376178462f1b61c941e]"
# [132] "   - conda-forge/linux-64::libnsl==2.0.1=hd590300_0[md5=30fd6e37fe21f86f4bd26d6ee73eeec7]"
# [133] "   - conda-forge/linux-64::libstdcxx-ng==14.1.0=h4852527_1[md5=bd2598399a70bb86d8218e95548d735e]"
# [134] "   - conda-forge/linux-64::libuuid==2.38.1=h0b41bf4_0[md5=40b61aab5c7ba9ff276c41cfffe6b80b]"
# [135] "   - conda-forge/linux-64::libxcrypt==4.4.36=hd590300_1[md5=5aa797f8787fe7a17d1b0821485b5adc]"
# [136] "   - conda-forge/linux-64::libzlib==1.3.1=h4ab18f5_1[md5=57d7dc60e9325e3de37ff8dffd18e814]"
# [137] "   - conda-forge/linux-64::lzo==2.10=hd590300_1001[md5=ec7398d21e2651e0dcb0044d03b9a339]"
# [138] "   - conda-forge/linux-64::ncurses==6.5=he02047a_1[md5=70caf8bb6cf39a0b6b7efc885f51c0fe]"
# [139] "   - conda-forge/linux-64::openssl==3.3.1=hb9d3cd8_3[md5=6c566a46baae794daf34775d41eb180a]"
# [140] "   - conda-forge/linux-64::reproc==14.2.4.post0=hd590300_1[md5=82ca53502dfd5a64a80dee76dae14685]"
# [141] "   - conda-forge/linux-64::xz==5.2.6=h166bdaf_0[md5=2161070d867d1b1204ea749c8eec4ef0]"
# [142] "   - conda-forge/linux-64::fmt==10.2.1=h00ab1b0_0[md5=35ef8bc24bd34074ebae3c943d551728]"
# [143] "   - conda-forge/linux-64::icu==75.1=he02047a_0[md5=8b189310083baabfb622af68fd9d3ae3]"
# [144] "   - conda-forge/linux-64::libedit==3.1.20191231=he28a2e2_2[md5=4d331e44109e3f0e19b4cb8f9b82f3e1]"
# [145] "   - conda-forge/linux-64::libnghttp2==1.58.0=h47da74e_1[md5=700ac6ea6d53d5510591c4344d5c989a]"
# [146] "   - conda-forge/linux-64::libsolv==0.7.30=h3509ff9_0[md5=02539b77d25aa4f65b20246549e256c3]"
# [147] "   - conda-forge/linux-64::libsqlite==3.46.1=hadc24fc_0[md5=36f79405ab16bf271edb55b213836dac]"
# [148] "   - conda-forge/linux-64::libssh2==1.11.0=h0841786_0[md5=1f5a58e686b13bcfde88b93f547d23fe]"
# [149] "   - conda-forge/linux-64::lz4-c==1.9.4=hcb278e6_0[md5=318b08df404f9c9be5712aaa5a6f0bb0]"
# [150] "   - conda-forge/linux-64::readline==8.2=h8228510_1[md5=47d31b792659ce70f470b5c82fdfb7a4]"
# [151] "   - conda-forge/linux-64::reproc-cpp==14.2.4.post0=h59595ed_1[md5=715e1d720ec1a03715bebd237972fca5]"
# [152] "   - conda-forge/linux-64::tk==8.6.13=noxft_h4845f30_101[md5=d453b98d9c83e71da0741bb0ff4d76bc]"
# [153] "   - conda-forge/linux-64::yaml-cpp==0.8.0=h59595ed_0[md5=965eaacd7c18eb8361fd12bb9e7a57d7]"
# [154] "   - conda-forge/linux-64::zstd==1.5.6=ha6fb4c9_0[md5=4d056880988120e29d75bfff282e0f45]"
# [155] "   - conda-forge/linux-64::krb5==1.21.3=h659f571_0[md5=3f43953b7d3fb3aaa1d0d0723d91e368]"
# [156] "   - conda-forge/linux-64::libxml2==2.12.7=he7c6b58_4[md5=08a9265c637230c37cb1be4a6cad4536]"
# [157] "   - conda-forge/linux-64::python==3.12.5=h2ad013b_0_cpython[md5=9c56c4df45f6571b13111d8df2448692]"
# [158] "   - conda-forge/linux-64::libarchive==3.7.4=hfca40fe_0[md5=32ddb97f897740641d8d46a829ce1704]"
# [159] "   - conda-forge/linux-64::libcurl==8.9.1=hdb1bdb2_0[md5=7da1d242ca3591e174a3c7d82230d3c0]"
# [160] "   - conda-forge/linux-64::menuinst==2.1.2=py312h7900ff3_1[md5=c6575ae996f2bc0369c73b632db5ca61]"
# [161] "   - conda-forge/noarch::archspec==0.2.3=pyhd8ed1ab_0[md5=192278292e20704f663b9c766909d67b]"
# [162] "   - conda-forge/noarch::boltons==24.0.0=pyhd8ed1ab_0[md5=61de176bd62041f9cd5bd4fcd09eb0ff]"
# [163] "   - conda-forge/linux-64::brotli-python==1.1.0=py312h2ec8cdc_2[md5=b0b867af6fc74b2a0aa206da29c0f3cf]"
# [164] "   - conda-forge/noarch::certifi==2024.8.30=pyhd8ed1ab_0[md5=12f7d00853807b0531775e9be891cb11]"
# [165] "   - conda-forge/noarch::charset-normalizer==3.3.2=pyhd8ed1ab_0[md5=7f4a9e3fcff3f6356ae99244a014da6a]"
# [166] "   - conda-forge/noarch::colorama==0.4.6=pyhd8ed1ab_0[md5=3faab06a954c2a04039983f2c4a50d99]"
# [167] "   - conda-forge/noarch::distro==1.9.0=pyhd8ed1ab_0[md5=bbdb409974cd6cb30071b1d978302726]"
# [168] "   - conda-forge/linux-64::frozendict==2.4.4=py312h9a8786e_0[md5=ff14ec1103a0817d45e7cf012742ce60]"
# [169] "   - conda-forge/noarch::hpack==4.0.0=pyh9f0ad1d_0[md5=914d6646c4dbb1fd3ff539830a12fd71]"
# [170] "   - conda-forge/noarch::hyperframe==6.0.1=pyhd8ed1ab_0[md5=9f765cbfab6870c8435b9eefecd7a1f4]"
# [171] "   - conda-forge/noarch::idna==3.8=pyhd8ed1ab_0[md5=99e164522f6bdf23c177c8d9ae63f975]"
# [172] "   - conda-forge/linux-64::jsonpointer==3.0.0=py312h7900ff3_1[md5=6b51f7459ea4073eeb5057207e2e1e3d]"
# [173] "   - conda-forge/linux-64::libmamba==1.5.9=h4cc3d14_0[md5=896cece5b883ad86e9dd88b1f4d23c99]"
# [174] "   - conda-forge/noarch::packaging==24.1=pyhd8ed1ab_0[md5=cbe1bb1f21567018ce595d9c2be0f0db]"
# [175] "   - conda-forge/noarch::platformdirs==4.2.2=pyhd8ed1ab_0[md5=6f6cf28bf8e021933869bae3f84b8fc9]"
# [176] "   - conda-forge/noarch::pluggy==1.5.0=pyhd8ed1ab_0[md5=d3483c8fc2dc2cc3f5cf43e26d60cabf]"
# [177] "   - conda-forge/linux-64::pycosat==0.6.6=py312h98912ed_0[md5=8f1c372e7b843167be885dc8229931c1]"
# [178] "   - conda-forge/noarch::pycparser==2.22=pyhd8ed1ab_0[md5=844d9eb3b43095b031874477f7d70088]"
# [179] "   - conda-forge/noarch::pysocks==1.7.1=pyha2e5f31_6[md5=2a7de29fb590ca14b5243c4c812c8025]"
# [180] "   - conda-forge/linux-64::ruamel.yaml.clib==0.2.8=py312h98912ed_0[md5=05f31c2a79ba61df8d6d903ce4a4ce7b]"
# [181] "   - conda-forge/noarch::setuptools==73.0.1=pyhd8ed1ab_0[md5=f0b618d7673d1b2464f600b34d912f6f]"
# [182] "   - conda-forge/noarch::truststore==0.9.2=pyhd8ed1ab_0[md5=f14e46d1bf271e748ff556d8b872e28a]"
# [183] "   - conda-forge/noarch::wheel==0.44.0=pyhd8ed1ab_0[md5=d44e3b085abcaef02983c6305b84b584]"
# [184] "   - conda-forge/linux-64::cffi==1.17.0=py312h06ac9bb_1[md5=db9bdbaee0f524ead0471689f002781e]"
# [185] "   - conda-forge/noarch::h2==4.1.0=pyhd8ed1ab_0[md5=b748fbf7060927a6e82df7cb5ee8f097]"
# [186] "   - conda-forge/noarch::jsonpatch==1.33=pyhd8ed1ab_0[md5=bfdb7c5c6ad1077c82a69a8642c87aff]"
# [187] "   - conda-forge/linux-64::libmambapy==1.5.9=py312h7fb9e8e_0[md5=ccaeeb6e3caaf0c744480393791aa366]"
# [188] "   - conda-forge/noarch::pip==24.2=pyh8b19718_1[md5=6c78fbb8ddfd64bcb55b5cbafd2d2c43]"
# [189] "   - conda-forge/linux-64::ruamel.yaml==0.18.6=py312h98912ed_0[md5=a99a06a875138829ef65f44bbe2c30ca]"
# [190] "   - conda-forge/noarch::tqdm==4.66.5=pyhd8ed1ab_0[md5=c6e94fc2b2ec71ea33fe7c7da259acb4]"
# [191] "   - conda-forge/linux-64::zstandard==0.23.0=py312hef9b889_1[md5=8b7069e9792ee4e5b4919a7a306d2e67]"
# [192] "   - conda-forge/noarch::conda-package-streaming==0.10.0=pyhd8ed1ab_0[md5=3480386e00995f7a1dfb3b9aa2fe70fd]"
# [193] "   - conda-forge/noarch::urllib3==2.2.2=pyhd8ed1ab_1[md5=e804c43f58255e977093a2298e442bb8]"
# [194] "   - conda-forge/noarch::conda-package-handling==2.3.0=pyh7900ff3_0[md5=0a7dce281ae2be81acab0aa963e6bb99]"
# [195] "   - conda-forge/noarch::requests==2.32.3=pyhd8ed1ab_0[md5=5ede4753180c7a550a443c430dc8ab52]"
# [196] "   - conda-forge/linux-64::conda==24.7.1=py312h7900ff3_0[md5=e1bf59014e88eaff036101358f63a496]"
# [197] "   - conda-forge/noarch::conda-libmamba-solver==24.7.0=pyhd8ed1ab_0[md5=857c9e25f0a77c0bd7eb622d46d9418f]"
# [198] "   - conda-forge/linux-64::mamba==1.5.9=py312h9460a1c_0[md5=a8525c8a1647b4f5967fa6b552722851]"
# [199] ""
# [200] ""
# [201] "  Package                         Version  Build               Channel         Size"
# [202] "─────────────────────────────────────────────────────────────────────────────────────"
# [203] "  Install:"
# [204] "─────────────────────────────────────────────────────────────────────────────────────"
# [205] ""
# [206] "  + _libgcc_mutex                     0.1  conda_forge         conda-forge         "
# [207] "  + ca-certificates             2024.8.30  hbcca054_0          conda-forge         "
# [208] "  + ld_impl_linux-64                 2.40  hf3520f5_7          conda-forge         "
# [209] "  + pybind11-abi                        4  hd8ed1ab_3          conda-forge         "
# [210] "  + python_abi                       3.12  5_cp312             conda-forge         "
# [211] "  + tzdata                          2024a  h8827d51_1          conda-forge         "
# [212] "  + libgomp                        14.1.0  h77fa898_1          conda-forge         "
# [213] "  + _openmp_mutex                     4.5  2_gnu               conda-forge         "
# [214] "  + libgcc                         14.1.0  h77fa898_1          conda-forge         "
# [215] "  + libgcc-ng                      14.1.0  h69a702a_1          conda-forge         "
# [216] "  + libstdcxx                      14.1.0  hc0a3c3a_1          conda-forge         "
# [217] "  + bzip2                           1.0.8  h4bc722e_7          conda-forge         "
# [218] "  + c-ares                         1.32.3  h4bc722e_0          conda-forge         "
# [219] "  + keyutils                        1.6.1  h166bdaf_0          conda-forge         "
# [220] "  + libev                            4.33  hd590300_2          conda-forge         "
# [221] "  + libexpat                        2.6.2  h59595ed_0          conda-forge         "
# [222] "  + libffi                          3.4.2  h7f98852_5          conda-forge         "
# [223] "  + libiconv                         1.17  hd590300_2          conda-forge         "
# [224] "  + libnsl                          2.0.1  hd590300_0          conda-forge         "
# [225] "  + libstdcxx-ng                   14.1.0  h4852527_1          conda-forge         "
# [226] "  + libuuid                        2.38.1  h0b41bf4_0          conda-forge         "
# [227] "  + libxcrypt                      4.4.36  hd590300_1          conda-forge         "
# [228] "  + libzlib                         1.3.1  h4ab18f5_1          conda-forge         "
# [229] "  + lzo                              2.10  hd590300_1001       conda-forge         "
# [230] "  + ncurses                           6.5  he02047a_1          conda-forge         "
# [231] "  + openssl                         3.3.1  hb9d3cd8_3          conda-forge         "
# [232] "  + reproc                   14.2.4.post0  hd590300_1          conda-forge         "
# [233] "  + xz                              5.2.6  h166bdaf_0          conda-forge         "
# [234] "  + fmt                            10.2.1  h00ab1b0_0          conda-forge         "
# [235] "  + icu                              75.1  he02047a_0          conda-forge         "
# [236] "  + libedit                  3.1.20191231  he28a2e2_2          conda-forge         "
# [237] "  + libnghttp2                     1.58.0  h47da74e_1          conda-forge         "
# [238] "  + libsolv                        0.7.30  h3509ff9_0          conda-forge         "
# [239] "  + libsqlite                      3.46.1  hadc24fc_0          conda-forge         "
# [240] "  + libssh2                        1.11.0  h0841786_0          conda-forge         "
# [241] "  + lz4-c                           1.9.4  hcb278e6_0          conda-forge         "
# [242] "  + readline                          8.2  h8228510_1          conda-forge         "
# [243] "  + reproc-cpp               14.2.4.post0  h59595ed_1          conda-forge         "
# [244] "  + tk                             8.6.13  noxft_h4845f30_101  conda-forge         "
# [245] "  + yaml-cpp                        0.8.0  h59595ed_0          conda-forge         "
# [246] "  + zstd                            1.5.6  ha6fb4c9_0          conda-forge         "
# [247] "  + krb5                           1.21.3  h659f571_0          conda-forge         "
# [248] "  + libxml2                        2.12.7  he7c6b58_4          conda-forge         "
# [249] "  + python                         3.12.5  h2ad013b_0_cpython  conda-forge         "
# [250] "  + libarchive                      3.7.4  hfca40fe_0          conda-forge         "
# [251] "  + libcurl                         8.9.1  hdb1bdb2_0          conda-forge         "
# [252] "  + menuinst                        2.1.2  py312h7900ff3_1     conda-forge         "
# [253] "  + archspec                        0.2.3  pyhd8ed1ab_0        conda-forge         "
# [254] "  + boltons                        24.0.0  pyhd8ed1ab_0        conda-forge         "
# [255] "  + brotli-python                   1.1.0  py312h2ec8cdc_2     conda-forge         "
# [256] "  + certifi                     2024.8.30  pyhd8ed1ab_0        conda-forge         "
# [257] "  + charset-normalizer              3.3.2  pyhd8ed1ab_0        conda-forge         "
# [258] "  + colorama                        0.4.6  pyhd8ed1ab_0        conda-forge         "
# [259] "  + distro                          1.9.0  pyhd8ed1ab_0        conda-forge         "
# [260] "  + frozendict                      2.4.4  py312h9a8786e_0     conda-forge         "
# [261] "  + hpack                           4.0.0  pyh9f0ad1d_0        conda-forge         "
# [262] "  + hyperframe                      6.0.1  pyhd8ed1ab_0        conda-forge         "
# [263] "  + idna                              3.8  pyhd8ed1ab_0        conda-forge         "
# [264] "  + jsonpointer                     3.0.0  py312h7900ff3_1     conda-forge         "
# [265] "  + libmamba                        1.5.9  h4cc3d14_0          conda-forge         "
# [266] "  + packaging                        24.1  pyhd8ed1ab_0        conda-forge         "
# [267] "  + platformdirs                    4.2.2  pyhd8ed1ab_0        conda-forge         "
# [268] "  + pluggy                          1.5.0  pyhd8ed1ab_0        conda-forge         "
# [269] "  + pycosat                         0.6.6  py312h98912ed_0     conda-forge         "
# [270] "  + pycparser                        2.22  pyhd8ed1ab_0        conda-forge         "
# [271] "  + pysocks                         1.7.1  pyha2e5f31_6        conda-forge         "
# [272] "  + ruamel.yaml.clib                0.2.8  py312h98912ed_0     conda-forge         "
# [273] "  + setuptools                     73.0.1  pyhd8ed1ab_0        conda-forge         "
# [274] "  + truststore                      0.9.2  pyhd8ed1ab_0        conda-forge         "
# [275] "  + wheel                          0.44.0  pyhd8ed1ab_0        conda-forge         "
# [276] "  + cffi                           1.17.0  py312h06ac9bb_1     conda-forge         "
# [277] "  + h2                              4.1.0  pyhd8ed1ab_0        conda-forge         "
# [278] "  + jsonpatch                        1.33  pyhd8ed1ab_0        conda-forge         "
# [279] "  + libmambapy                      1.5.9  py312h7fb9e8e_0     conda-forge         "
# [280] "  + pip                              24.2  pyh8b19718_1        conda-forge         "
# [281] "  + ruamel.yaml                    0.18.6  py312h98912ed_0     conda-forge         "
# [282] "  + tqdm                           4.66.5  pyhd8ed1ab_0        conda-forge         "
# [283] "  + zstandard                      0.23.0  py312hef9b889_1     conda-forge         "
# [284] "  + conda-package-streaming        0.10.0  pyhd8ed1ab_0        conda-forge         "
# [285] "  + urllib3                         2.2.2  pyhd8ed1ab_1        conda-forge         "
# [286] "  + conda-package-handling          2.3.0  pyh7900ff3_0        conda-forge         "
# [287] "  + requests                       2.32.3  pyhd8ed1ab_0        conda-forge         "
# [288] "  + conda                          24.7.1  py312h7900ff3_0     conda-forge         "
# [289] "  + conda-libmamba-solver          24.7.0  pyhd8ed1ab_0        conda-forge         "
# [290] "  + mamba                           1.5.9  py312h9460a1c_0     conda-forge         "
# [291] ""
# [292] "  Summary:"
# [293] ""
# [294] "  Install: 85 packages"
# [295] ""
# [296] "  Total download: 0 B"
# [297] ""
# [298] "─────────────────────────────────────────────────────────────────────────────────────"
# [299] ""
# [300] ""
# [301] ""
# [302] "Transaction starting"
# [303] ""
# [304] "Transaction finished"
# [305] ""
# [306] "To activate this environment, use:"
# [307] ""
# [308] "    micromamba activate /home/ec2-user/mambaforge"
# [309] ""
# [310] "Or to execute a single command in this environment, use:"
# [311] ""
# [312] "    micromamba run -p /home/ec2-user/mambaforge mycommand"
# [313] ""
# [314] "installation finished."

# %%
# Install gsutil and dependencies using mamba
system('mamba install -y -c conda-forge -c bioconda gsutil', intern = TRUE)
# Out:
#  [1] "bioconda/linux-64                                           Using cache"
#  [2] "bioconda/noarch                                             Using cache"
#  [3] "nvidia/linux-64                                             Using cache"
#  [4] "nvidia/noarch                                               Using cache"
#  [5] "pytorch/linux-64                                            Using cache"
#  [6] "pytorch/noarch                                              Using cache"
#  [7] "Transaction"
#  [8] ""
#  [9] "  Prefix: /home/ec2-user/anaconda3/envs/R"
# [10] ""
# [11] "  All requested packages already installed"
# [12] ""
# [13] ""
# [14] "Looking for: ['gsutil']"
# [15] ""
# [16] ""
# [17] "Pinned packages:"
# [18] "  - python 3.11.*"
# [19] ""
# [20] ""

# %%
# Out:
# character(0)
# character(0)

# %% [markdown]
# ### STEP 1: Library Installation
#
# First install the R packages that will be used. <strong>This installation may take around 15 minutes.</strong>

# %%
# Install BiocManager if not installed
if (!requireNamespace("BiocManager", quietly = TRUE))
    install.packages("BiocManager")

# Set repositories
options(repos = BiocManager::repositories())

# Install Bioconductor packages
BiocManager::install(c("ComplexHeatmap", "DESeq2", "EnhancedVolcano"), force = TRUE)

# Install CRAN packages
install.packages(c("dplyr", "pheatmap", "ggrepel", "ggfortify"), dependencies = TRUE)
# Out:
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     CRAN: https://cran.r-project.org
#
# 'getOption("repos")' replaces Bioconductor standard repositories, see
# 'help("repositories", package = "BiocManager")' for details.
# Replacement repositories:
#     BioCsoft: https://bioconductor.org/packages/3.19/bioc
#     BioCann: https://bioconductor.org/packages/3.19/data/annotation
#     BioCexp: https://bioconductor.org/packages/3.19/data/experiment
#     BioCworkflows: https://bioconductor.org/packages/3.19/workflows
#     BioCbooks: https://bioconductor.org/packages/3.19/books
#     CRAN: https://cran.r-project.org
#
# Bioconductor version 3.19 (BiocManager 1.30.25), R 4.4.1 (2024-06-14)
#
# Installing package(s) 'BiocVersion', 'ComplexHeatmap', 'DESeq2',
#   'EnhancedVolcano'
#
# also installing the dependencies ‘UCSC.utils’, ‘GenomeInfoDbData’, ‘zlibbioc’, ‘abind’, ‘SparseArray’, ‘lambda.r’, ‘futile.options’, ‘rjson’, ‘GenomeInfoDb’, ‘XVector’, ‘S4Arrays’, ‘DelayedArray’, ‘futile.logger’, ‘snow’, ‘BH’, ‘circlize’, ‘GetoptLong’, ‘clue’, ‘GlobalOptions’, ‘IRanges’, ‘matrixStats’, ‘doParallel’, ‘S4Vectors’, ‘GenomicRanges’, ‘SummarizedExperiment’, ‘BiocGenerics’, ‘Biobase’, ‘BiocParallel’, ‘locfit’, ‘MatrixGenerics’, ‘RcppArmadillo’, ‘ggrepel’
#
#
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done
#
# Old packages: 'curl', 'data.table', 'MASS', 'Matrix', 'nlme', 'ps', 'ragg'
#
# also installing the dependencies ‘credentials’, ‘zip’, ‘gitcreds’, ‘ini’, ‘rbibutils’, ‘bitops’, ‘gert’, ‘gh’, ‘whisker’, ‘downlit’, ‘httr2’, ‘xopen’, ‘brew’, ‘gss’, ‘stabledist’, ‘gbutils’, ‘Rdpack’, ‘gtools’, ‘caTools’, ‘RSpectra’, ‘profmem’, ‘rex’, ‘plogr’, ‘brio’, ‘desc’, ‘pkgload’, ‘praise’, ‘waldo’, ‘diffobj’, ‘polynom’, ‘usethis’, ‘miniUI’, ‘pkgbuild’, ‘pkgdown’, ‘profvis’, ‘rcmdcheck’, ‘remotes’, ‘roxygen2’, ‘rversions’, ‘sessioninfo’, ‘urlchecker’, ‘beeswarm’, ‘vipor’, ‘fBasics’, ‘fastICA’, ‘cvar’, ‘fracdiff’, ‘lmtest’, ‘urca’, ‘cyclocomp’, ‘xmlparsedata’, ‘terra’, ‘gplots’, ‘sandwich’, ‘quadprog’, ‘rARPACK’, ‘bench’, ‘covr’, ‘Lahman’, ‘microbenchmark’, ‘nycflights13’, ‘RMySQL’, ‘RPostgreSQL’, ‘RSQLite’, ‘testthat’, ‘svglite’, ‘vdiffr’, ‘gridExtra’, ‘ggpp’, ‘patchwork’, ‘devtools’, ‘prettydoc’, ‘ggbeeswarm’, ‘changepoint’, ‘fGarch’, ‘forecast’, ‘KFAS’, ‘lintr’, ‘mapdata’, ‘markdown’, ‘MSwM’, ‘raster’, ‘ROCR’, ‘sp’, ‘strucchange’, ‘timeSeries’, ‘tseries’, ‘vars’, ‘lfda’
#
#
# Warning message in install.packages(c("dplyr", "pheatmap", "ggrepel", "ggfortify"), :
# “installation of package ‘terra’ had non-zero exit status”
# Warning message in install.packages(c("dplyr", "pheatmap", "ggrepel", "ggfortify"), :
# “installation of package ‘RMySQL’ had non-zero exit status”
# Warning message in install.packages(c("dplyr", "pheatmap", "ggrepel", "ggfortify"), :
# “installation of package ‘RPostgreSQL’ had non-zero exit status”
# Warning message in install.packages(c("dplyr", "pheatmap", "ggrepel", "ggfortify"), :
# “installation of package ‘raster’ had non-zero exit status”
# Updating HTML index of packages in '.Library'
#
# Making 'packages.html' ...
#  done

# %%
# Load libraries
library(DESeq2)
library(dplyr)
library(ComplexHeatmap)
library(EnhancedVolcano)
library(ggplot2)
library(ggrepel)
library(ggfortify)
# Out:
# Loading required package: S4Vectors
#
# Loading required package: stats4
#
# Loading required package: BiocGenerics
#
#
# Attaching package: ‘BiocGenerics’
#
#
# The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, intersect, is.unsorted, lapply, Map, mapply,
#     match, mget, order, paste, pmax, pmax.int, pmin, pmin.int,
#     Position, rank, rbind, Reduce, rownames, sapply, setdiff, table,
#     tapply, union, unique, unsplit, which.max, which.min
#
#
#
# Attaching package: ‘S4Vectors’
#
#
# The following object is masked from ‘package:utils’:
#
#     findMatches
#
#
# The following objects are masked from ‘package:base’:
#
#     expand.grid, I, unname
#
#
# Loading required package: IRanges
#
# Loading required package: GenomicRanges
#
# Loading required package: GenomeInfoDb
#
# Loading required package: SummarizedExperiment
#
# Loading required package: MatrixGenerics
#
# Loading required package: matrixStats
#
#
# Attaching package: ‘MatrixGenerics’
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     colAlls, colAnyNAs, colAnys, colAvgsPerRowSet, colCollapse,
#     colCounts, colCummaxs, colCummins, colCumprods, colCumsums,
#     colDiffs, colIQRDiffs, colIQRs, colLogSumExps, colMadDiffs,
#     colMads, colMaxs, colMeans2, colMedians, colMins, colOrderStats,
#     colProds, colQuantiles, colRanges, colRanks, colSdDiffs, colSds,
#     colSums2, colTabulates, colVarDiffs, colVars, colWeightedMads,
#     colWeightedMeans, colWeightedMedians, colWeightedSds,
#     colWeightedVars, rowAlls, rowAnyNAs, rowAnys, rowAvgsPerColSet,
#     rowCollapse, rowCounts, rowCummaxs, rowCummins, rowCumprods,
#     rowCumsums, rowDiffs, rowIQRDiffs, rowIQRs, rowLogSumExps,
#     rowMadDiffs, rowMads, rowMaxs, rowMeans2, rowMedians, rowMins,
#     rowOrderStats, rowProds, rowQuantiles, rowRanges, rowRanks,
#     rowSdDiffs, rowSds, rowSums2, rowTabulates, rowVarDiffs, rowVars,
#     rowWeightedMads, rowWeightedMeans, rowWeightedMedians,
#     rowWeightedSds, rowWeightedVars
#
#
# Loading required package: Biobase
#
# Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
#
# Attaching package: ‘Biobase’
#
#
# The following object is masked from ‘package:MatrixGenerics’:
#
#     rowMedians
#
#
# The following objects are masked from ‘package:matrixStats’:
#
#     anyMissing, rowMedians
#
#
#
# Attaching package: ‘dplyr’
#
#
# The following object is masked from ‘package:Biobase’:
#
#     combine
#
#
# The following object is masked from ‘package:matrixStats’:
#
#     count
#
#
# The following objects are masked from ‘package:GenomicRanges’:
#
#     intersect, setdiff, union
#
#
# The following object is masked from ‘package:GenomeInfoDb’:
#
#     intersect
#
#
# The following objects are masked from ‘package:IRanges’:
#
#     collapse, desc, intersect, setdiff, slice, union
#
#
# The following objects are masked from ‘package:S4Vectors’:
#
#     first, intersect, rename, setdiff, setequal, union
#
#
# The following objects are masked from ‘package:BiocGenerics’:
#
#     combine, intersect, setdiff, union
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
#
#
# Loading required package: grid
#
# ========================================
# ComplexHeatmap version 2.20.0
# Bioconductor page: http://bioconductor.org/packages/ComplexHeatmap/
# Github page: https://github.com/jokergoo/ComplexHeatmap
# Documentation: http://jokergoo.github.io/ComplexHeatmap-reference
#
# If you use it in published research, please cite either one:
# - Gu, Z. Complex Heatmap Visualization. iMeta 2022.
# - Gu, Z. Complex heatmaps reveal patterns and correlations in multidimensional
#     genomic data. Bioinformatics 2016.
#
#
# The new InteractiveComplexHeatmap package can directly export static
# complex heatmaps into an interactive Shiny app with zero effort. Have a try!
#
# This message can be suppressed by:
#   suppressPackageStartupMessages(library(ComplexHeatmap))
# ========================================
#
#
# Loading required package: ggplot2
#
# Loading required package: ggrepel

# %%
system("aws --version")
system("aws configure list")
system("aws s3 ls s3://your-aws-bucket/salmon/")

# %% [markdown]
# ### STEP 2: Reading in Data
#
# Next read-in the gene count data that will be analyzed.
#
# This read-in step often involves reformatting or adjusting the data.
#
# To make things easier, we created a matrix, or a table, of just our read-count data -- excluding the non-numerical metadata columns. This makes it easy for us to feed this table into the deseq2 tool later on.
#
# Additionally, later on we will use normalization involving logarithms. So, to prevent errors, we will replace all readcount values of '0' in our data, with '1'. This will change the data only slightly, and will prevent these zeroes from causing an 'undefined' or 'N/A' math error in the logarithm normalization step.

# %%
# Check if the directories exist before creating them
if (!dir.exists("data/gene_counts")) {
  dir.create("data/gene_counts", recursive = TRUE)
}

if (!dir.exists("data/reference")) {
  dir.create("data/reference", recursive = TRUE)
}

# Download gene counts and annotation file from the Google Cloud bucket using gsutil
system('gsutil cp gs://rnaseq-myco-bucket/salmon/SRP300216_merged_quants.txt data/gene_counts/SRP300216_genecounts.txt', intern = TRUE)
system('gsutil cp gs://rnaseq-myco-bucket/reference/GCF_001632805.1_ASM163280v1_feature_table.txt data/reference/GCF_001632805.1_ASM163280v1_feature_table.txt', intern = TRUE)
# Out:
# character(0)
# character(0)

# %%
#read-in the raw gene count file to a dataframe variable we named 'read_counts'
read_counts <- read.table('data/gene_counts/SRP300216_genecounts.txt',head=TRUE)

#amount of columns the dataframe has
cols = ncol(read_counts)

#assign the numerical read counts to a matrix variable we named 'rnaseqMatrix'
rnaseqMatrix <- round(read_counts[,c(2:cols)])

#label the rownames of this matrix with the rowname column from the gene count dataframe.
rownames(rnaseqMatrix) <- read_counts[,1]

head(rnaseqMatrix)
# Out:
#              GSM5004088 GSM5004089 GSM5004090 GSM5004091 GSM5004092 GSM5004093
# BB28_RS24845  118        94        105         45         36         46
# BB28_RS24840  308       296        288        101         81        137
# BB28_RS24300 1020       834        931        352        259        405
# BB28_RS24270    3         4          0          1          0          3
# BB28_RS24265   26        14         17          5          6          9
# BB28_RS24255   19        21         16         29         30         56

# %% [markdown]
# ### STEP 3: Specifying Experimental Design
#
# Next specify the experimental design.
#
# The deseq2 tool will later use this design to group samples together, and output information about the statistical differences in gene expression between these specified groups.

# %%
# define the sample experimental design, in this case 3 wildtype and 3 bacteriophage infected samples
samples_treatment <- data.frame(matrix(c(rep("WT",3),rep("BPs_lysogen",3)),ncol=1))
samples_ID <- data.frame(matrix(colnames(rnaseqMatrix),ncol=1))
samples <- cbind(samples_ID,samples_treatment)
names(samples) <- c("ID","Treatment")
rownames(samples) <- samples[,1]

print("An example of how a deseq2 experimental design table might look.")
samples
# Out:
# [1] "An example of how a deseq2 experimental design table might look."
#            ID         Treatment
# GSM5004088 GSM5004088 WT
# GSM5004089 GSM5004089 WT
# GSM5004090 GSM5004090 WT
# GSM5004091 GSM5004091 BPs_lysogen
# GSM5004092 GSM5004092 BPs_lysogen
# GSM5004093 GSM5004093 BPs_lysogen

# %% [markdown]
# ### STEP 4: Creating Deseq2 Object
#
# Now use the treatment design matrix in combination with the readcount matrix to create a deseq2 object.
#
# Once created, this is also a good opportunity to filter out lowly expresseed genes, and to inspect the pre-normalized data using pairwise comparison plots. These example plots, the pairwise plot and boxplot, can be used to examine gene expression distributions and highlight outliers.
#
# Finally, the deseq2 analysis can be run on the deseq2 object.

# %%
#Create the DEseq2DataSet object
deseq2Data <- DESeqDataSetFromMatrix(countData = rnaseqMatrix, colData = samples, design = ~ Treatment)

# Perform pre-filtering of the data (deseq2 also automatically does this, but can this can increase speed)
deseq2Data <- deseq2Data[rowSums(counts(deseq2Data)) > 10, ]

# Inspect pre-normalized data 
pairs(log2((counts(deseq2Data)+1)))
boxplot(log2((counts(deseq2Data)+1)))

# Run pipeline for differential expression steps
deseq2Data <- DESeq(deseq2Data)
# Out:
# converting counts to integer mode
#
# Warning message in DESeqDataSet(se, design = design, ignoreRank):
# “some variables in design formula are characters, converting to factors”
# plot without title
# estimating size factors
#
# estimating dispersions
#
# gene-wise dispersion estimates
#
# mean-dispersion relationship
#
# final dispersion estimates
#
# fitting model and testing
# plot without title

# %% [markdown]
# ### STEP 5: Normalize Data
#
# DESeq2 automatically normalizes data in the DESeq() step using a method called median of ratios. For our own downstream analysis we can pick from several different normalization methods. As an example, here we use rlog transformation, or regularized log transformation to normalize data. This method is similar to log normalization, but includes a 'shrinkage' estimator to attempt to shrink the variance of the log-transformed data. More information for this and other normalization methods can be found in the DESeq2 documentation.
#
# Normalization of gene readcounts across samples will help to minimize sample variation noise and ensure more accurate comparisons. Looking at normalized plots can be an easy way to look out for any obvious inconsistencies or errors in the sample data.

# %%
#perform rlog normalization on deseq2 object
rld <- rlog(deseq2Data, blind=FALSE)

#a handy variable so we can easily reference the rlog genecount matrix in the future, as deseq objects contain many tables of data.
rlogcounts <- assay(rld)
rownames(rlogcounts) <- rownames(deseq2Data)

head(rlogcounts)
# Out:
#              GSM5004088 GSM5004089 GSM5004090 GSM5004091 GSM5004092 GSM5004093
# BB28_RS24845 6.4097497  6.3184522  6.4248340  5.8591462  5.7894407  5.6517859
# BB28_RS24840 7.8662624  7.9802134  7.9454474  7.0222765  6.9327428  7.0479614
# BB28_RS24300 9.6229173  9.5410091  9.6794730  8.7312088  8.5130326  8.5679423
# BB28_RS24270 0.7795705  0.8253392  0.6838981  0.7313994  0.6927364  0.7869511
# BB28_RS24265 3.8139750  3.5930635  3.6707460  3.3762240  3.4465121  3.4336746
# BB28_RS24255 4.4496337  4.5733255  4.4445161  4.8888634  4.9896759  5.1839448

# %% [markdown]
# Normalization of data can is often verified by inspecting by various plots, such as histograms (these typically follow a negative binomial distribution, as shown below):

# %%
hist(rlogcounts)
# Out:
# Plot with title “Histogram of rlogcounts”

# %% [markdown]
# Boxplots:

# %%
boxplot(rlogcounts)
# Out:
# plot without title

# %% [markdown]
# Or pairwise comparison plots. Notice how sample groups can be visualized just by looking at the pairwise plot.

# %%
pairs(rlogcounts)
# Out:
# plot without title

# %% [markdown]
# Compare the plots of the pre-normalized and normalized data to see the effect of normalization.
#
# Notice how the samples in the box plot, and in-group samples in the pair plots display similar distributions.
#
# Looking at normalized plots can be an easy way to look out for any obvious inconsistencies or errors in the sample data.

# %% [markdown]
# ### STEP 6: PCA Plot
#
# We can now begin to produce plots to further analyze the differences between groups.
#
# PCA plots can be an effective way to visualize variation within and between sample sets.

# %%
pca_counts <- prcomp(t(rlogcounts))
autoplot(pca_counts, data = samples, colour="Treatment", size=6)
# Out:
# plot without title

# %% [markdown]
# Plots can be output as above, or also saved as pdf or image files, as below. Try to navigate and click to the created file, after you run the code.
#
# Tiff files can also be created this way.

# %%
pdf("data/gene_counts/PCA_Plot.pdf")
autoplot(pca_counts, data = samples, colour="Treatment", size=6)
dev.off()

tiff("data/gene_counts/PCA_Plot.tiff")
autoplot(pca_counts, data = samples, colour="Treatment", size=6)
dev.off()
# Out:
# png
#   2
# png
#   2

# %% [markdown]
# ### STEP 7: Contrast Comparisons
#
# Contrast comparisons between two treatment groups can be performed using the deseq2 tool to identify differentially up and down regulated genes.
#
# Using R, these results can be summarized, reordered, and/or trimmed.
#
# Differentially expressed genes are typically quantified as those genes which have an adjusted P value of below 0.05. An adjusted P value is also sometimes referred to as a false discovery rate, or FDR. In the below, there are 1357 differentially expressed genes. For the sake of reducing the amount of differentially expressed genes, to make analyses easier, these could also be further refined by introducing a threshold based on fold-change. DEseq2 uses the Wald and Benjamini-Hochberg tests for determining P and Adjusted P values, respectively. More information on this can be found in the DEseq2 documentation.

# %%
#Output the results of comparing WT and BPs_lysogen group
res_WT_BPs <- results(deseq2Data, contrast=c("Treatment","WT","BPs_lysogen"))
summary(res_WT_BPs)
print("Number of genes under a p value of 0.05")
sum(res_WT_BPs$pvalue < 0.05, na.rm=TRUE)
print("Number of genes under a p adjusted value of 0.05")
sum(res_WT_BPs$padj < 0.05, na.rm=TRUE)


#deseq2 optionally output some padj values as 'NA' when genecounts meet certain criteria
#that criteria can be found here: https://bioconductor.org/packages/release/bioc/vignettes/DESeq2/inst/doc/DESeq2.html#pvaluesNA
#for practical uses, one could replace the NA values with '1', essentially NA values not significant.
res_WT_BPs$padj[is.na(res_WT_BPs$padj)] <- 1
# Out:
# out of 4605 with nonzero total read count
# adjusted p-value < 0.1
# LFC > 0 (up)       : 819, 18%
# LFC < 0 (down)     : 813, 18%
# outliers [1]       : 0, 0%
# low counts [2]     : 179, 3.9%
# (mean count < 3)
# [1] see 'cooksCutoff' argument of ?results
# [2] see 'independentFiltering' argument of ?results
#
# [1] "Number of genes under a p value of 0.05"
# [1] 1763
# [1] "Number of genes under a p adjusted value of 0.05"
# [1] 1357

# %% [markdown]
# ### STEP 8: Annotating and Exporting Results
#
# These differentially expressed genes can be annotated and exported.
#
# Combining gene counts with gene annotation isn't always simple, and will vary heavily depending on the annotation file itself.
#
# For example, when merging genecounts by 'gene id' with feature tables from NCBI's assembly database, its very common to have duplicate rows, as a single 'gene id' may match to multiple features.
#
# Depending on how you want to use your annotated results, you may decide to further reformat your table in whatever suits your further analysis best, for instance by downloading and using a spreadsheet editor.
#
# Because the transcript table for m chelonae we have here is so simple, and contains essentially only one 'CDS' or '..RNA' feature for every gene identifier we are using, it is easy for us to reformat it here in the way we want just using R code. However, it is important to note that, again, this is very often not the case, and reformatting will vary depending on both the annotation file itself, and what that annotation file will be used for.

# %%
#read-in the annotation file (see extended tutorial for more info on how to get annotation files) and store it into a variable.
annotation <- read.table("data/reference/GCF_001632805.1_ASM163280v1_feature_table.txt", header=TRUE,sep='\t', quote="\"",comment.char = "")

#put the previous deseq results into an easier to manipulate data.frame format
results <- data.frame(res_WT_BPs)

#merge the annotation with the deseq2 contrast comparison table
results.annot <- merge(results,annotation,by.x=0,by.y=17,all.x=TRUE)



#Open the annotation file above to see the format. If you further download and examine in a spreadsheet editor,
#you can see there is one CDS or ..RNA identifier for each 'gene' feature
#this makes reformatting in R simple by just removing every 'gene' feature, and leaving the more detailed 'cds' or '...RNA' feature.
#this is very often not always the case, but simple and easy here.
results.annot <- results.annot[annotation$X..feature!='gene',]

#labeling the columns properly after the merge
colnames(results.annot)[1] <- 'locus_tag'

#write out the file
write.table(results.annot,"data/gene_counts/WT_BPs_DESeq2_annot.txt",row.names=FALSE,sep="\t")

head(results.annot)
# Out:
#    locus_tag    baseMean  log2FoldChange lfcSE     stat      pvalue
# 2  BB28_RS00005  465.5947  0.66733104    0.1158310  5.761246 8.349511e-09
# 4  BB28_RS00010  312.4363  0.25993860    0.1280622  2.029784 4.237853e-02
# 6  BB28_RS00015  340.6501  0.57232028    0.1326868  4.313317 1.608232e-05
# 8  BB28_RS00020  100.3025  0.89863440    0.1982573  4.532668 5.824337e-06
# 10 BB28_RS00025  113.1915  0.50491799    0.1930194  2.615892 8.899472e-03
# 12 BB28_RS00030 3311.5852 -0.09956595    0.0852011 -1.168599 2.425651e-01
#    padj         X..feature class          assembly        ⋯ strand
# 2  1.017006e-07 gene       protein_coding GCF_001632805.1 ⋯ +
# 4  1.115808e-01 gene       protein_coding GCF_001632805.1 ⋯ +
# 6  1.120950e-04 CDS        with_protein   GCF_001632805.1 ⋯ +
# 8  4.452248e-05 gene       protein_coding GCF_001632805.1 ⋯ +
# 10 3.181669e-02 gene       protein_coding GCF_001632805.1 ⋯ +
# 12 4.116538e-01 CDS        with_protein   GCF_001632805.1 ⋯ +
#    product_accession non.redundant_refseq related_accession
# 2                                         NA
# 4                                         NA
# 6  WP_046251966.1    WP_046251966.1       NA
# 8                                         NA
# 10                                        NA
# 12 WP_046251970.1    WP_046251970.1       NA
#    name                                             symbol GeneID
# 2                                                   dnaA   31677580
# 4                                                   dnaN   31677581
# 6  decarboxylating 6-phosphogluconate dehydrogenase gnd    31677582
# 8                                                   recF   31677583
# 10                                                         31677584
# 12 DNA topoisomerase (ATP-hydrolyzing) subunit B    gyrB   31677585
#    feature_interval_length product_length attributes
# 2  1476                     NA            old_locus_tag=BB28_00005
# 4  1200                     NA            old_locus_tag=BB28_00010
# 6   894                    297
# 8  1149                     NA            old_locus_tag=BB28_00020
# 10  552                     NA            old_locus_tag=BB28_00025
# 12 2028                    675

# %% [markdown]
# ### STEP 9: More Plots and Clustering Data
#
# Finally, although several other different kind of analysis can be done, it is common to plot the results of differential gene expression analysis in forms such as volcano, MA, and heatmaps. These plots help one to further examine the output list of differentially expressed genes in different ways, and potentially identify or further investigate candidate gene(s).

# %%
#volcano and ma plots can be used to visualize significant differences in gene expression
results_volc_df <- results.annot
EnhancedVolcano(results_volc_df,
    lab = results_volc_df[,1],
    x = 'log2FoldChange',
    y = 'padj')

#ma plot
plotMA(res_WT_BPs)


#heatmaps can used to look at clustering and expression of various gene lists.
filtered_res <- results.annot %>% filter(padj < 0.05)
filtered_res_counts <- subset(rlogcounts, rownames(rlogcounts) %in% filtered_res[,1])
filtered_res_counts = t(scale(t(filtered_res_counts)))
Heatmap(filtered_res_counts[1:50,], name = "Z-Score", row_names_gp = gpar(fontsize = 8))
# Out:
# plot without title
# Plot with title “”

# %% [markdown]
# ## <a name="workflow">Additional Workflows</a>

# %% [markdown]
# Now that you have ran some analysis on read count data, feel feel free to explore and revisit the previous workflows for creating readcounts, such as the standard or extended tutorials, or the snakemake tutorial.

# %% [markdown]
# [Workflow One:](Tutorial_1.ipynb) A short introduction to downloading and mapping sequences to a transcriptome using Trimmomatic and Salmon. Here is a link to the YouTube video demonstrating the tutorial: <https://youtu.be/ChGfBR4do_Y>.
#
# [Workflow One (Extended):](Tutorial_1B_Extended.ipynb) An extended version of workflow one. Once you have got your feet wet, you can retry workflow one with this extended version that covers the entire dataset, and includes elaboration such as using SRA tools for sequence downloading, and examples of running batches of fastq files through the pipeline. This workflow may take around an hour to run.
#
# [Workflow One (Using Snakemake):](Tutorial_2_Snakemake.ipynb) Using snakemake to run workflow one.
#
# [Workflow Two (DEG Analysis):](Tutorial_3_DEG_Analysis.ipynb) Using Deseq2 and R to conduct clustering and differential gene expression analysis.

# %% [markdown]
# ![RNA-Seq workflow](images/RNA-Seq_Notebook_Homepage.png)
